# %%
import pandas as pd

# %%
df=pd.read_excel("/content/highRisk.xlsm")
highriskcountries=df["ENTITY_KEY"].values.tolist()
highriskcountries
# Out:
# ['AF', 'JI', 'PK', 'IS', 'TR', 'SR']

# %%
df=pd.read_excel("/content/customer_ACCOUNT.xlsm")
accountKeys=df["account_key"].values.tolist()
primary_party_key=df["primary_party_key"].values.tolist()
acct_open_date=df["acct_open_date"].values.tolist()
accountInfo={}
for no,i in enumerate(accountKeys):
    accountInfo[i]={"primary_party_key":primary_party_key[no],"acct_open_date":acct_open_date[no]}
accountInfo
# Out:
# {'ANSP_34300169780270': {'acct_open_date': 1541548800000000000,
#   'primary_party_key': 'X35300017D_00'},
#  'AQSP_34300169780273': {'acct_open_date': 1541635200000000000,
#   'primary_party_key': 'X35300018D_00'},
#  'AQSP_D34300169780274': {'acct_open_date': 1541721600000000000,
#   'primary_party_key': 'X35300019D_00'},
#  'CASP_D00406002222111': {'acct_open_date': 1544227200000000000,
#   'primary_party_key': 'C014061110C_00'},
#  'CASP_D00406002222222': {'acct_open_date': 1544313600000000000,
#   'primary_party_key': 'C014061111C_00'},
#  'CASP_D00406002222333': {'acct_open_date': 1544400000000000000,
#   'primary_party_key': 'C014063330C_00'},
#  'CASP_D00406002222444': {'acct_open_date': 1544486400000000000,
#   'primary_party_key': 'C014063331C_00'},
#  'CASP_D00406002222555': {'acct_open_date': 1544572800000000000,
#   'primary_party_key': 'C014063332C_00'},
#  'CASP_D00406002222666': {'acct_open_date': 1544659200000000000,
#   'primary_party_key': 'C014062220C_00'},
#  'CASP_D00406002222777': {'acct_open_date': 1544745600000000000,
#   'primary_party_key': 'C014062222C_00'},
#  'CASP_D00406002222888': {'acct_open_date': 1544832000000000000,
#   'primary_party_key': 'C014063333C_00'},
#  'CASP_D00406002222999': {'acct_open_date': 1544918400000000000,
#   'primary_party_key': 'C014064444C_00'},
#  'CASP_D00630157111111': {'acct_open_date': 1543363200000000000,
#   'primary_party_key': 'C01570111G_00'},
#  'CASP_D00630157222222': {'acct_open_date': 1543449600000000000,
#   'primary_party_key': 'C01570222G_00'},
#  'CASP_D00630169780001': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C014581971C_00'},
#  'CASP_D00630169780002': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C014831981K_00'},
#  'CASP_D00630169780003': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C015471980N_00'},
#  'CASP_D00630169780004': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C016051974E_00'},
#  'CASP_D00630169780005': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C016801986E_00'},
#  'CASP_D00630169780006': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C017421985G_00'},
#  'CASP_D00630169780007': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C019501994H_00'},
#  'CASP_D00630169780008': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C019991997H_00'},
#  'CASP_D00630169780009': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C022571975M_00'},
#  'CASP_D00630169780010': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C023191978H_00'},
#  'CASP_D00630169780011': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C024781981H_00'},
#  'CASP_D00630169780012': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C025051990D_00'},
#  'CASP_D00630169780013': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C025451993E_00'},
#  'CASP_D00630169780014': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C026201978G_00'},
#  'CASP_D00630169780015': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C027501981Z_00'},
#  'CASP_D00630169780016': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C029371992H_00'},
#  'CASP_D00630169780017': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C029771987M_00'},
#  'CASP_D00630169780018': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C031221990N_00'},
#  'CASP_D00630169780019': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C031911982N_00'},
#  'CASP_D00630169780020': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C033521978Z_00'},
#  'CASP_D00630169780021': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C035381992W_00'},
#  'CASP_D00630169780022': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C038251990H_00'},
#  'CASP_D00630169780023': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C038701991C_00'},
#  'CASP_D00630169780024': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C041001983H_00'},
#  'CASP_D00630169780025': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C042521991G_00'},
#  'CASP_D00630169780026': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C042711998G_00'},
#  'CASP_D00630169780027': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C026611981H_00'},
#  'CASP_D00630169780028': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C044571982H_00'},
#  'CASP_D00630169780029': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C046211994G_00'},
#  'CASP_D00630169780030': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C046951981D_00'},
#  'CASP_D00630169780031': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C047171993K_00'},
#  'CASP_D00630169780032': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C047971980R_00'},
#  'CASP_D00630169780033': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C052551993D_00'},
#  'CASP_D00630169780034': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C058571991E_00'},
#  'CASP_D00630169780035': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C061181998E_00'},
#  'CASP_D00630169780036': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C073111994Z_00'},
#  'CASP_D00630169780037': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C074171997K_00'},
#  'CASP_D00630169780038': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C074421996K_00'},
#  'CASP_D00630169780039': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C082261996R_00'},
#  'CASP_D00630169780040': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C084511995E_00'},
#  'CASP_D00630169780041': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C125600016G_00'},
#  'CASP_D00630169780042': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C125600017K_00'},
#  'CASP_D00630169780043': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C125600021N_00'},
#  'CASP_D00630169780044': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C125600053W_00'},
#  'CASP_D00630169780045': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'R00742500K_00'},
#  'CASP_D00630169780046': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'R21061800X_00'},
#  'CASP_D00630169780047': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'X0019017823_00'},
#  'CASP_D00630169780048': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'X123992_00'},
#  'CASP_D00630169780049': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'X420739_00'},
#  'CASP_D00630169780050': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'A00102811119_00'},
#  'CASP_D00630169780051': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A0039016212_00'},
#  'CASP_D00630169780052': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A0039031947_00'},
#  'CASP_D00630169780053': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'A0050168953_00'},
#  'CASP_D00630169780054': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A0069021896_00'},
#  'CASP_D00630169780055': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A0089001566_00'},
#  'CASP_D00630169780056': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'A0089028618_00'},
#  'CASP_D00630169780057': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A0119042958_00'},
#  'CASP_D00630169780058': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A01486799_00'},
#  'CASP_D00630169780059': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'A0149030373_00'},
#  'CASP_D00630169780060': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A0149030535_00'},
#  'CASP_D00630169780061': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A0179010950_00'},
#  'CASP_D00630169780062': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'A0179039681_00'},
#  'CASP_D00630169780063': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A0189025676_00'},
#  'CASP_D00630169780064': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A02075733_00'},
#  'CASP_D00630169780065': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'A0209016366_00'},
#  'CASP_D00630169780066': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A0220220772_00'},
#  'CASP_D00630169780067': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A0279041668_00'},
#  'CASP_D00630169780068': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'A0279048611_00'},
#  'CASP_D00630169780069': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A03007936_00'},
#  'CASP_D00630169780070': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A031308020_00'},
#  'CASP_D00630169780071': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'A03149625_00'},
#  'CASP_D00630169780072': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A04062183_00'},
#  'CASP_D00630169780073': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A0479030140_00'},
#  'CASP_D00630169780074': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'A0479033602_00'},
#  'CASP_D00630169780075': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A0489030534_00'},
#  'CASP_D00630169780076': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A0489036001_00'},
#  'CASP_D00630169780077': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'A0549030996_00'},
#  'CASP_D00630169780078': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A0549031240_00'},
#  'CASP_D00630169780079': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A0549036820_00'},
#  'CASP_D00630169780080': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'A0659002218_00'},
#  'CASP_D00630169780081': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A0709007015_00'},
#  'CASP_D00630169780082': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A082951997_00'},
#  'CASP_D00630169780083': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'A10056268_00'},
#  'CASP_D00630169780084': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A1069029198_00'},
#  'CASP_D00630169780085': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A1079011365_00'},
#  'CASP_D00630169780086': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'A1079020275_00'},
#  'CASP_D00630169780087': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A1079032451_00'},
#  'CASP_D00630169780088': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A1079035710_00'},
#  'CASP_D00630169780089': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'A14055061_00'},
#  'CASP_D00630169780090': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A14093320_00'},
#  'CASP_D00630169780091': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A15046643_00'},
#  'CASP_D00630169780092': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'A28050615_00'},
#  'CASP_D00630169780093': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A2889002693_00'},
#  'CASP_D00630169780094': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A2889042539_00'},
#  'CASP_D00630169780095': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'A2889042750_00'},
#  'CASP_D00630169780096': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A33001070_00'},
#  'CASP_D00630169780097': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A33021275_00'},
#  'CASP_D00630169780098': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'A33024967_00'},
#  'CASP_D00630169780099': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A47036577_00'},
#  'CASP_D00630169780100': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A48020003_00'},
#  'CASP_D00630169780101': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'A48028284_00'},
#  'CASP_D00630169780102': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A66011755_00'},
#  'CASP_D00630169780103': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'A74847_00'},
#  'CASP_D00630169780104': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'AS25CS0001L_00'},
#  'CASP_D00630169780105': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'AS61SS0117F_00'},
#  'CASP_D00630169780106': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'AS62SS0001F_00'},
#  'CASP_D00630169780107': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'AS62SS0064B_00'},
#  'CASP_D00630169780108': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'AS62SS0076K_00'},
#  'CASP_D00630169780109': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'AS74SS0006K_00'},
#  'CASP_D00630169780110': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'AS75SS0058K_00'},
#  'CASP_D00630169780111': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'AS77SS0005G_00'},
#  'CASP_D00630169780112': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'AS80SS0043C_00'},
#  'CASP_D00630169780113': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'AS83SS0025L_00'},
#  'CASP_D00630169780114': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'AS84SS0019F_00'},
#  'CASP_D00630169780115': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'AS92SS0087J_00'},
#  'CASP_D00630169780116': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'AS96MC2029E_00'},
#  'CASP_D00630169780117': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'AS97SS0015G_00'},
#  'CASP_D00630169780118': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'AS97SS0045L_00'},
#  'CASP_D00630169780119': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'AS99SS0093K_00'},
#  'CASP_D00630169780120': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'ASALARXX100_00'},
#  'CASP_D00630169780121': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C000151999D_00'},
#  'CASP_D00630169780122': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C000191958C_00'},
#  'CASP_D00630169780123': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C000261995M_00'},
#  'CASP_D00630169780124': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C000281995N_00'},
#  'CASP_D00630169780125': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C000441986N_00'},
#  'CASP_D00630169780126': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C000591964D_00'},
#  'CASP_D00630169780127': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C000911963D_00'},
#  'CASP_D00630169780128': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C001381976N_00'},
#  'CASP_D00630169780129': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C001421988N_00'},
#  'CASP_D00630169780130': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C001561968Z_00'},
#  'CASP_D00630169780131': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C001591980N_00'},
#  'CASP_D00630169780132': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C001911977W_00'},
#  'CASP_D00630169780133': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C002221977N_00'},
#  'CASP_D00630169780134': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C004101986K_00'},
#  'CASP_D00630169780135': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C004461971K_00'},
#  'CASP_D00630169780136': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C004981982E_00'},
#  'CASP_D00630169780137': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C005241983K_00'},
#  'CASP_D00630169780138': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C006391971Z_00'},
#  'CASP_D00630169780139': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C006421977W_00'},
#  'CASP_D00630169780140': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C006651979D_00'},
#  'CASP_D00630169780141': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C007881983Z_00'},
#  'CASP_D00630169780142': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C007991977M_00'},
#  'CASP_D00630169780143': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C008071980K_00'},
#  'CASP_D00630169780144': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C008831970D_00'},
#  'CASP_D00630169780145': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C009671975N_00'},
#  'CASP_D00630169780146': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C010261996M_00'},
#  'CASP_D00630169780147': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C010431985R_00'},
#  'CASP_D00630169780148': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C012481979H_00'},
#  'CASP_D00630169780149': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C012871972D_00'},
#  'CASP_D00630169780150': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C012952002Z_00'},
#  'CASP_D00630169780151': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C013181991G_00'},
#  'CASP_D00630169780152': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C013211993K_00'},
#  'CASP_D00630169780153': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C014491977C_00'},
#  'CASP_D00630169780154': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'M160520016_00'},
#  'CASP_D00630169780155': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'M160520017_00'},
#  'CASP_D00630169780156': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'M160520018_00'},
#  'CASP_D00630169780157': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'M160520019_00'},
#  'CASP_D00630169780158': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'AT15MC0046J_00'},
#  'CASP_D00630169780159': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'AT13SS0022F_00'},
#  'CASP_D00630169780160': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'AT13SS0097K_00'},
#  'CASP_D00630169780161': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'AT13SS0163B_00'},
#  'CASP_D00630169780162': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'AT13SS0172L_00'},
#  'CASP_D00630169780163': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'AT14CC0003B_00'},
#  'CASP_D00630169780164': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'AT14SS0148K_00'},
#  'CASP_D00630169780165': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S9038913G_00'},
#  'CASP_D00630169780166': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S9138913G_00'},
#  'CASP_D00630169780167': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S9238913G_00'},
#  'CASP_D00630169780168': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S9338913G_00'},
#  'CASP_D00630169780169': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S9438913G_00'},
#  'CASP_D00630169780170': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S9538913G_00'},
#  'CASP_D00630169780171': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S9638913G_00'},
#  'CASP_D00630169780172': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S9738913G_00'},
#  'CASP_D00630169780173': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S9838913G_00'},
#  'CASP_D00630169780174': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S9938913G_00'},
#  'CASP_D00630169780175': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S9038923G_00'},
#  'CASP_D00630169780176': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S9138923G_00'},
#  'CASP_D00630169780177': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S9238923G_00'},
#  'CASP_D00630169780178': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S9338923G_00'},
#  'CASP_D00630169780179': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S9438923G_00'},
#  'CASP_D00630169780180': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S9538923G_00'},
#  'CASP_D00630169780181': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S9638923G_00'},
#  'CASP_D00630169780182': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S9738923G_00'},
#  'CASP_D00630169780183': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S9838923G_00'},
#  'CASP_D00630169780184': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S9938923G_00'},
#  'CASP_D00630169780185': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S9038933G_00'},
#  'CASP_D00630169780186': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S9138933G_00'},
#  'CASP_D00630169780187': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S9238933G_00'},
#  'CASP_D00630169780188': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S9338933G_00'},
#  'CASP_D00630169780189': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S9438933G_00'},
#  'CASP_D00630169780190': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S7138923G_00'},
#  'CASP_D00630169780191': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S7238923G_00'},
#  'CASP_D00630169780192': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S7338923G_00'},
#  'CASP_D00630169780193': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S7438923G_00'},
#  'CASP_D00630169780194': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S7538923G_00'},
#  'CASP_D00630169780195': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S7638923G_00'},
#  'CASP_D00630169780196': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S7738923G_00'},
#  'CASP_D00630169780197': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S7838923G_00'},
#  'CASP_D00630169780198': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S7938923G_00'},
#  'CASP_D00630169780199': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S7038933G_00'},
#  'CASP_D00630169780200': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'X123992_00 '},
#  'CASP_D00630169780201': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'X420739_00'},
#  'CASP_D00630169780202': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'M040919830309_00'},
#  'CASP_D00630169780203': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'M050919830309_00'},
#  'CASP_D00630169780204': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'M010844004_00'},
#  'CASP_D00630169780205': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'AT08SS0246D_00'},
#  'CASP_D00630169780206': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'AT09MC0060E_00'},
#  'CASP_D00630169780207': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'AT10SS0048K_00'},
#  'CASP_D00630169780208': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'AT11CC0007D_00'},
#  'CASP_D00630169780209': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'AT11SS0212F_00'},
#  'CASP_D00630169780210': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C831911982N_00'},
#  'CASP_D00630169780211': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C833521978Z_00'},
#  'CASP_D00630169780212': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C835381992W_00'},
#  'CASP_D00630169780213': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C838251990H_00'},
#  'CASP_D00630169780214': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C838701991C_00'},
#  'CASP_D00630169780215': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C841001983H_00'},
#  'CASP_D00630169780216': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C842521991G_00'},
#  'CASP_D00630169780217': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C842711998G_00'},
#  'CASP_D00630169780218': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C844571982H_00'},
#  'CASP_D00630169780219': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C846211994G_00'},
#  'CASP_D00630169780220': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C846951981D_00'},
#  'CASP_D00630169780221': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C847171993K_00'},
#  'CASP_D00630169780222': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C847971980R_00'},
#  'CASP_D00630169780223': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C852551993D_00'},
#  'CASP_D00630169780224': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C858571991E_00'},
#  'CASP_D00630169780225': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C861181998E_00'},
#  'CASP_D00630169780226': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C873111994Z_00'},
#  'CASP_D00630169780227': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C874171997K_00'},
#  'CASP_D00630169780228': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C874421996K_00'},
#  'CASP_D00630169780229': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C882261996R_00'},
#  'CASP_D00630169780230': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C884511995E_00'},
#  'CASP_D00630169780231': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S8138923G_00'},
#  'CASP_D00630169780232': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S8238923G_00'},
#  'CASP_D00630169780233': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S8338923G_00'},
#  'CASP_D00630169780234': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S8438923G_00'},
#  'CASP_D00630169780235': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C546951981D_00'},
#  'CASP_D00630169780236': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C547171993K_00'},
#  'CASP_D00630169780237': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C547971980R_00'},
#  'CASP_D00630169780238': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C552551993D_00'},
#  'CASP_D00630169780239': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C558571991E_00'},
#  'CASP_D00630169780240': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C561181998E_00'},
#  'CASP_D00630169780241': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C573111994Z_00'},
#  'CASP_D00630169780242': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C574171997K_00'},
#  'CASP_D00630169780243': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C574421996K_00'},
#  'CASP_D00630169780244': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C582261996R_00'},
#  'CASP_D00630169780245': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C584511995E_00'},
#  'CASP_D00630169780246': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'S1659194G_00'},
#  'CASP_D00630169780247': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C15046643_00'},
#  'CASP_D00630169780248': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'M860520015_00'},
#  'CASP_D00630169780249': {'acct_open_date': 1430352000000000000,
#   'primary_party_key': 'S0035195D_00'},
#  'CASP_D00630169780250': {'acct_open_date': 1433030400000000000,
#   'primary_party_key': 'S0035322A_00'},
#  'CASP_D00630169780251': {'acct_open_date': 1435622400000000000,
#   'primary_party_key': 'S0035345J_00'},
#  'CASP_D00630169780252': {'acct_open_date': 1438300800000000000,
#   'primary_party_key': 'S0035397C_00'},
#  'CASP_D00630169780253': {'acct_open_date': 1440979200000000000,
#   'primary_party_key': 'S0036415J_00'},
#  'CASP_D00630169780254': {'acct_open_date': 1443571200000000000,
#   'primary_party_key': 'S0036469Z_00'},
#  'CASP_D00630412222000': {'acct_open_date': 1543536000000000000,
#   'primary_party_key': 'C04120000G_00'},
#  'CASP_D00630412222111': {'acct_open_date': 1543622400000000000,
#   'primary_party_key': 'C04120111G_00'},
#  'CASP_D00630412222222': {'acct_open_date': 1543708800000000000,
#   'primary_party_key': 'C04120222G_00'},
#  'CASP_D00630412222333': {'acct_open_date': 1543795200000000000,
#   'primary_party_key': 'C04120333G_00'},
#  'CASP_D00630412222444': {'acct_open_date': 1543881600000000000,
#   'primary_party_key': 'C04120444G_00'},
#  'CASP_D00630412222555': {'acct_open_date': 1543968000000000000,
#   'primary_party_key': 'C04120555G_00'},
#  'CASP_D00630412222666': {'acct_open_date': 1544054400000000000,
#   'primary_party_key': 'C04120666G_00'},
#  'CASP_D00630412222777': {'acct_open_date': 1544140800000000000,
#   'primary_party_key': 'C04120777G_00'},
#  'CASP_D04050165300009': {'acct_open_date': 1425081600000000000,
#   'primary_party_key': 'C1245363788_00'},
#  'CASP_D19900122220211': {'acct_open_date': 1599782400000000000,
#   'primary_party_key': 'X199900011D_00'},
#  'CASP_D19900122220212': {'acct_open_date': 1628726400000000000,
#   'primary_party_key': 'S199900011F_00'},
#  'CASP_D20100169780240': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C0588S30F3A_00'},
#  'CASP_D20100169780241': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C201227388N_00'},
#  'CASP_D20100169780242': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C0654S20F4A_00'},
#  'CASP_D20100169780243': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C340062019C_00'},
#  'CASP_D20100169780244': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C396302019D_00'},
#  'CASP_D20100169780245': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C29964200C_00'},
#  'CASP_D20100169780246': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C34119000D_00'},
#  'CASP_D20100169780247': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'T09CC0004J_00'},
#  'CASP_D20100169780248': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'R53402322C_00'},
#  'CASP_D20100169780249': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C008542003M_00'},
#  'CASP_D20100169780250': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C008542010G_00'},
#  'CASP_D20100169780251': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C008551982Z_00'},
#  'CASP_D20100169780252': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C008551993H_00'},
#  'CASP_D20100169780253': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C179762011E_00'},
#  'CASP_D20100169780254': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C179762016D_00'},
#  'CASP_D20100169780255': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C179772008R_00'},
#  'CASP_D20100169780256': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C179772009Z_00'},
#  'CASP_D20100169780257': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'D468914C_00'},
#  'CASP_D20100169780258': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'D47043000_00'},
#  'CASP_D20100169780259': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'DS141822_00'},
#  'CASP_D20100169780260': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'R53402399A_00'},
#  'CASP_D20100169780261': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C428622019R_00'},
#  'CASP_D20100169780262': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C315012019K_00'},
#  'CASP_D20100169780263': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C315032019M_00'},
#  'CASP_D20100169780264': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'DS109962_00'},
#  'CASP_D20100169780265': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'GTANZTZTX_00'},
#  'CASP_D20100169780266': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'GUNITARXVIII_00'},
#  'CASP_D20100169780267': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'PT175711_00'},
#  'CASP_D20100169780268': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C004412020H_00'},
#  'CASP_D20100169780269': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'PKJ0734171_01'},
#  'CASP_D20100169780270': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C02790FH_00'},
#  'CASP_D20100169780271': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'P18FV08030_01'},
#  'CASP_D20100169780272': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'DS212766_00'},
#  'CASP_D20100169780273': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'R53402364M_00'},
#  'CASP_D20100169780274': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'R53402365K_00'},
#  'CASP_D20100169780275': {'acct_open_date': 1427846400000000000,
#   'primary_party_key': 'DS249944_00'},
#  'CASP_D20100169780276': {'acct_open_date': 1427932800000000000,
#   'primary_party_key': 'PBM74KH953_01'},
#  'CASP_D28700122220000': {'acct_open_date': 1541808000000000000,
#   'primary_party_key': 'X287100011D_00'},
#  'CASP_D33590169780249': {'acct_open_date': 1380153600000000000,
#   'primary_party_key': 'C359600016G_00'},
#  'CASP_D33590169780250': {'acct_open_date': 1380240000000000000,
#   'primary_party_key': 'C359600016G_00'},
#  'CASP_D34300122220211': {'acct_open_date': 1570838400000000000,
#   'primary_party_key': 'C343000222H_00'},
#  'CASP_D34300169780211': {'acct_open_date': 1569888000000000000,
#   'primary_party_key': 'C343000011H_00'},
#  'CASP_D34300169780212': {'acct_open_date': 1569974400000000000,
#   'primary_party_key': 'C343000012H_00'},
#  'CASP_D34300169780213': {'acct_open_date': 1570060800000000000,
#   'primary_party_key': 'C343000021H_00'},
#  'CASP_D34300169780214': {'acct_open_date': 1570147200000000000,
#   'primary_party_key': 'C343000022H_00'},
#  'CASP_D34300169780215': {'acct_open_date': 1570233600000000000,
#   'primary_party_key': 'C343000031H_00'},
#  'CASP_D34300169780216': {'acct_open_date': 1544054400000000000,
#   'primary_party_key': 'C343000031H_00'},
#  'CASP_D34300169780217': {'acct_open_date': 1570233600000000000,
#   'primary_party_key': 'C343000032H_00'},
#  'CASP_D34300169780218': {'acct_open_date': 1544054400000000000,
#   'primary_party_key': 'C343000032H_00'},
#  'CASP_D34300169780219': {'acct_open_date': 1570233600000000000,
#   'primary_party_key': 'C343000033H_00'},
#  'CASP_D34300169780220': {'acct_open_date': 1544054400000000000,
#   'primary_party_key': 'C343000033H_00'},
#  'CASP_D34300169780221': {'acct_open_date': 1570233600000000000,
#   'primary_party_key': 'C343000034H_00'},
#  'CASP_D34300169780222': {'acct_open_date': 1544054400000000000,
#   'primary_party_key': 'C343000034H_00'},
#  'CASP_D34300169780223': {'acct_open_date': 1570233600000000000,
#   'primary_party_key': 'C343000041H_00'},
#  'CASP_D34300169780224': {'acct_open_date': 1544054400000000000,
#   'primary_party_key': 'C343000041H_00'},
#  'CASP_D34300169780225': {'acct_open_date': 1570233600000000000,
#   'primary_party_key': 'C343000042H_00'},
#  'CASP_D34300169780226': {'acct_open_date': 1544054400000000000,
#   'primary_party_key': 'C343000042H_00'},
#  'CASP_D34300169780227': {'acct_open_date': 1569888000000000000,
#   'primary_party_key': 'C343000051H_00'},
#  'CASP_D34300169780228': {'acct_open_date': 1569974400000000000,
#   'primary_party_key': 'C343000061H_00'},
#  'CASP_D34300169780229': {'acct_open_date': 1570060800000000000,
#   'primary_party_key': 'C343000071H_00'},
#  'CASP_D34300169780230': {'acct_open_date': 1570147200000000000,
#   'primary_party_key': 'C343000081H_00'},
#  'CASP_D34300169780231': {'acct_open_date': 1569888000000000000,
#   'primary_party_key': 'C343000091H_00'},
#  'CASP_D34300169780232': {'acct_open_date': 1569974400000000000,
#   'primary_party_key': 'C343000101H_00'},
#  'CASP_D34300169780233': {'acct_open_date': 1570147200000000000,
#   'primary_party_key': 'C343000111H_00'},
#  'CASP_D34300169780234': {'acct_open_date': 1543881600000000000,
#   'primary_party_key': 'C343000111H_00'},
#  'CASP_D34300169780235': {'acct_open_date': 1543968000000000000,
#   'primary_party_key': 'S87698751A_00'},
#  'CASP_D34300169780236': {'acct_open_date': 1544054400000000000,
#   'primary_party_key': 'S87698752S_00'},
#  'CASP_D34300169780237': {'acct_open_date': 1538352000000000000,
#   'primary_party_key': 'M87698753D_00'},
#  'CASP_D34300169780238': {'acct_open_date': 1538438400000000000,
#   'primary_party_key': 'M87698754F_00'},
#  'CASP_D34300169780239': {'acct_open_date': 1538524800000000000,
#   'primary_party_key': 'S87698755G_00'},
#  'CASP_D34300169780240': {'acct_open_date': 1538611200000000000,
#   'primary_party_key': 'S87698756H_00'},
#  'CASP_D34300169780241': {'acct_open_date': 1538697600000000000,
#   'primary_party_key': 'M87698757J_00'},
#  'CASP_D34300169780242': {'acct_open_date': 1538784000000000000,
#   'primary_party_key': 'M87698758K_00'},
#  'CASP_D34300169780243': {'acct_open_date': 1538870400000000000,
#   'primary_party_key': 'S87698759L_00'},
#  'CASP_D34300169780244': {'acct_open_date': 1538956800000000000,
#   'primary_party_key': 'S88698750Z_00'},
#  'CASP_D34300169780245': {'acct_open_date': 1539043200000000000,
#   'primary_party_key': 'S88698751X_00'},
#  'CASP_D34300169780246': {'acct_open_date': 1539129600000000000,
#   'primary_party_key': 'S88698752C_00'},
#  'CASP_D34300169780247': {'acct_open_date': 1539216000000000000,
#   'primary_party_key': 'M88698753V_00'},
#  'CASP_D34300169780248': {'acct_open_date': 1539302400000000000,
#   'primary_party_key': 'M88698754B_00'},
#  'CASP_D34300169780249': {'acct_open_date': 1539388800000000000,
#   'primary_party_key': 'S88698755N_00'},
#  'CASP_D34300169780250': {'acct_open_date': 1539475200000000000,
#   'primary_party_key': 'S88698756N_00'},
#  'CASP_D34300169780251': {'acct_open_date': 1539561600000000000,
#   'primary_party_key': 'M88698757M_00'},
#  'CASP_D34300169780252': {'acct_open_date': 1539648000000000000,
#   'primary_party_key': 'M88698758Q_00'},
#  'CASP_D34300169780253': {'acct_open_date': 1539734400000000000,
#   'primary_party_key': 'S88698759W_00'},
#  'CASP_D34300169780254': {'acct_open_date': 1539820800000000000,
#   'primary_party_key': 'S89698750E_00'},
#  'CASP_D34300169780255': {'acct_open_date': 1539907200000000000,
#   'primary_party_key': 'S89698751R_00'},
#  'CASP_D34300169780256': {'acct_open_date': 1539993600000000000,
#   'primary_party_key': 'S89698752T_00'},
#  'CASP_D34300169780257': {'acct_open_date': 1540080000000000000,
#   'primary_party_key': 'M89698753Y_00'},
#  'CASP_D34300169780258': {'acct_open_date': 1540166400000000000,
#   'primary_party_key': 'M89698754U_00'},
#  'CASP_D34300169780259': {'acct_open_date': 1540252800000000000,
#   'primary_party_key': 'S89698755I_00'},
#  'CASP_D34300169780260': {'acct_open_date': 1540339200000000000,
#   'primary_party_key': 'S89698756O_00'},
#  'CASP_D34300169780261': {'acct_open_date': 1540425600000000000,
#   'primary_party_key': 'M89698757P_00'},
#  'CASP_D34300169780262': {'acct_open_date': 1540512000000000000,
#   'primary_party_key': 'M89698758A_00'},
#  'CASP_D34300169780263': {'acct_open_date': 1540598400000000000,
#   'primary_party_key': 'S89698759S_00'},
#  'CASP_D34300169780264': {'acct_open_date': 1540857600000000000,
#   'primary_party_key': 'S87198752G_00'},
#  'CASP_D34300169780265': {'acct_open_date': 1540944000000000000,
#   'primary_party_key': 'M87198753H_00'},
#  'CASP_D34300169780266': {'acct_open_date': 1541030400000000000,
#   'primary_party_key': 'X35300011D_00'},
#  'CASP_D34300169780267': {'acct_open_date': 1541116800000000000,
#   'primary_party_key': 'X35300012D_00'},
#  'CASP_D34300169780268': {'acct_open_date': 1541203200000000000,
#   'primary_party_key': 'X35300013D_00'},
#  'CASP_D34300169780280': {'acct_open_date': 1541808000000000000,
#   'primary_party_key': 'X35300022D_00'},
#  'CASP_D34300169780291': {'acct_open_date': 1541894400000000000,
#   'primary_party_key': 'X35300033D_00'},
#  'CASP_D35230169780240': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C353222220C_00'},
#  'CASP_D35230169780241': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C353222221C_00'},
#  'CASP_D35230169780242': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C352222222C_00'},
#  'CASP_D35230169780243': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C353222223C_00'},
#  'CASP_D35230169780244': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C353222224C_00'},
#  'CASP_D35230169780245': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C353222225C_00'},
#  'CASP_D35230169780246': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C353222226C_00'},
#  'CASP_D35230169780247': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C353222227C_00'},
#  'CASP_D35230169780248': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C353222228C_00'},
#  'CASP_D35230169780249': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C353222229C_00'},
#  'CASP_D35630169780241': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C3560001D_00'},
#  'CASP_D35630169780242': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C3560002D_00'},
#  'CASP_D35630169780243': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C3560003D_00'},
#  'CASP_D35630169780244': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C3560004D_00'},
#  'CASP_D35630169780245': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C3560005D_00'},
#  'CASP_D35630169780246': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'C3560006D_00'},
#  'CASP_D35630169780247': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S1111111G_00'},
#  'CASP_D35630169780248': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S1111112G_00'},
#  'CASP_D35630169780249': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S1111113G_00'},
#  'CASP_D35630169780250': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S1111114G_00'},
#  'CASP_D35630169780251': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S1111115G_00'},
#  'CASP_D35630169780252': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S1111116G_00'},
#  'CASP_D35630169780253': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S1111117G_00'},
#  'CASP_D35630169780254': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S1111118G_00'},
#  'CASP_D35630169780255': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S1111119G_00'},
#  'CASP_D35630169780256': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S1111120G_00'},
#  'CASP_D35630169780257': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S1111121G_00'},
#  'CASP_D35630169780258': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S1111122G_00'},
#  'CASP_D35630169780259': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S1111123G_00'},
#  'CASP_D35630169780260': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S1111124G_00'},
#  'CASP_D35630169780261': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S1111125G_00'},
#  'CASP_D35630169780262': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S1111126G_00'},
#  'CASP_D35630169780263': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S1111127G_00'},
#  'CASP_D35630169780264': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S1111128G_00'},
#  'CASP_D35630169780265': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S1111129G_00'},
#  'CASP_D35630169780266': {'acct_open_date': 1427760000000000000,
#   'primary_party_key': 'S1111130G_00'},
#  'CASP_D36030169780241': {'acct_open_date': 1600041600000000000,
#   'primary_party_key': 'C36000001C_00'},
#  'CASP_D36030169780242': {'acct_open_date': 1600214400000000000,
#   'primary_party_key': 'C36000002C_00'},
#  'CASP_D36030169780243': {'acct_open_date': 1379203200000000000,
#   'primary_party_key': 'C36000003C_00'},
#  'CASP_D37130169780241': {'acct_open_date': 1379289600000000000,
#   'primary_party_key': 'C3710001N_00'},
#  'CASP_D37230169780241': {'acct_open_date': 1379376000000000000,
#   'primary_party_key': 'C3720000D_00'},
#  'CASP_D37230169780242': {'acct_open_date': 1379462400000000000,
#   'primary_party_key': 'C3720001D_00'},
#  'CASP_D37230169780243': {'acct_open_date': 1379548800000000000,
#   'primary_party_key': 'C3720002D_00'},
#  'CASP_D37230169780244': {'acct_open_date': 1379635200000000000,
#   'primary_party_key': 'S3720000F_00'},
#  'CASP_D37230169780245': {'acct_open_date': 1379721600000000000,
#   'primary_party_key': 'S3720001F_00'},
#  'CASP_D37230169780246': {'acct_open_date': 1379808000000000000,
#   'primary_party_key': 'S3720002F_00'},
#  'CASP_D37230169780247': {'acct_open_date': 1379894400000000000,
#   'primary_party_key': 'C3730000N_00'},
#  'CASP_D37230169780248': {'acct_open_date': 1379980800000000000,
#   'primary_party_key': 'C355111110C_00'},
#  'CASP_D37230169780249': {'acct_open_date': 1380067200000000000,
#   'primary_party_key': 'C355111111C_00'},
#  'CASP_D37700169780111': {'acct_open_date': 1541808000000000000,
#   'primary_party_key': 'C37700111N_00'},
#  'CASP_D37700169780222': {'acct_open_date': 1541894400000000000,
#   'primary_party_key': 'C37700222N_00'},
#  'CASP_D40000000001111': {'acct_open_date': 1542931200000000000,
#   'primary_party_key': 'C040011119_00'},
#  'CASP_D40000000002222': {'acct_open_date': 1543017600000000000,
#   'primary_party_key': 'M0400123R_00'},
#  'CASP_D40300122220000': {'acct_open_date': 1541894400000000000,
#   'primary_party_key': 'AS40300019F_00'},
#  'CASP_D40500169711110': {'acct_open_date': 1541980800000000000,
#   'primary_party_key': 'C405000010H_00'},
#  'CASP_D40500169711111': {'acct_open_date': 1542067200000000000,
#   'primary_party_key': 'C405000011H_00'},
#  'CASP_D40500169733330': {'acct_open_date': 1542240000000000000,
#   'primary_party_key': 'C405000330H_00'},
#  'CASP_D40500169733331': {'acct_open_date': 1542326400000000000,
#   'primary_party_key': 'C405000331H_00'},
#  'CASP_D40500169744440': {'acct_open_date': 1542412800000000000,
#   'primary_party_key': 'C405000440H_00'},
#  'CASP_D40500169755550': {'acct_open_date': 1542499200000000000,
#   'primary_party_key': 'C405000550H_00'},
#  'CASP_D40500169755551': {'acct_open_date': 1542585600000000000,
#   'primary_party_key': 'C405000551H_00'},
#  'CASP_D40500169766661': {'acct_open_date': 1542672000000000000,
#   'primary_party_key': 'C405000660H_00'},
#  'CASP_D40500169777770': {'acct_open_date': 1542758400000000000,
#   'primary_party_key': 'C405000770H_00'},
#  'CASP_D40500169777771': {'acct_open_date': 1542844800000000000,
#   'primary_party_key': 'C405000771H_00'},
#  'CASP_D40500169780222': {'acct_open_date': 1542153600000000000,
#   'primary_party_key': 'C405000022H_00'},
#  'CASP_D40500169799999': {'acct_open_date': 1543017600000000000,
#   'primary_party_key': 'C405000999H_00'},
#  'CASP_D40500169888888': {'acct_open_date': 1542931200000000000,
#   'primary_party_key': 'C405000880H_00'},
#  'CASP_D41300000001111': {'acct_open_date': 1541894400000000000,
#   'primary_party_key': 'C04130111G_00'},
#  'CASP_D41300000001123': {'acct_open_date': 1542672000000000000,
#   'primary_party_key': 'C04130123G_00'},
#  'CASP_D41300000002222': {'acct_open_date': 1541980800000000000,
#   'primary_party_key': 'C04130222G_00'},
#  'CASP_D41300000002456': {'acct_open_date': 1542758400000000000,
#   'primary_party_key': 'C04130456G_00'},
#  'CASP_D41300000003333': {'acct_open_date': 1542067200000000000,
#   'primary_party_key': 'C04130333G_00'},
#  'CASP_D41300000003789': {'acct_open_date': 1542844800000000000,
#   'primary_party_key': 'C04130789G_00'},
#  'CASP_D41300000004444': {'acct_open_date': 1542153600000000000,
#   'primary_party_key': 'C04130444G_00'},
#  'CASP_D41300000005555': {'acct_open_date': 1542240000000000000,
#   'primary_party_key': 'C04130555G_00'},
#  'CASP_D41300000006666': {'acct_open_date': 1542326400000000000,
#   'primary_party_key': 'C04130666G_00'},
#  'CASP_D41300000007777': {'acct_open_date': 1542412800000000000,
#   'primary_party_key': 'C04130777G_00'},
#  'CASP_D41300000008888': {'acct_open_date': 1542499200000000000,
#   'primary_party_key': 'C04130888G_00'},
#  'CASP_D41300000009999': {'acct_open_date': 1542585600000000000,
#   'primary_party_key': 'C04130999G_00'},
#  'CASP_D43700000001111': {'acct_open_date': 1543104000000000000,
#   'primary_party_key': 'C043711119_00'},
#  'CASP_D43700000002222': {'acct_open_date': 1543190400000000000,
#   'primary_party_key': 'M0437123R_00'},
#  'CASP_D43700000003333': {'acct_open_date': 1543276800000000000,
#   'primary_party_key': 'M0437456R_00'},
#  'CASP_P34300169780269': {'acct_open_date': 1541289600000000000,
#   'primary_party_key': 'X35300014D_00'},
#  'DQSP_D34300169780271': {'acct_open_date': 1541376000000000000,
#   'primary_party_key': 'X35300015D_00'},
#  'DQSP_P34300169780272': {'acct_open_date': 1541462400000000000,
#   'primary_party_key': 'X35300016D_00'},
#  nan: {'acct_open_date': None, 'primary_party_key': nan}}

# %%
acct_open_date
# Out:
# [1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1425081600000000000,
#  1425081600000000000,
#  1427760000000000000,
#  1430352000000000000,
#  1433030400000000000,
#  1435622400000000000,
#  1438300800000000000,
#  1440979200000000000,
#  1443571200000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1600041600000000000,
#  1600214400000000000,
#  1379203200000000000,
#  1379289600000000000,
#  1379376000000000000,
#  1379462400000000000,
#  1379548800000000000,
#  1379635200000000000,
#  1379721600000000000,
#  1379808000000000000,
#  1379894400000000000,
#  1379980800000000000,
#  1380067200000000000,
#  1380153600000000000,
#  1380240000000000000,
#  None,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427760000000000000,
#  1427846400000000000,
#  1427932800000000000,
#  1569888000000000000,
#  1569974400000000000,
#  1570060800000000000,
#  1570147200000000000,
#  1570233600000000000,
#  1544054400000000000,
#  1570233600000000000,
#  1544054400000000000,
#  1570233600000000000,
#  1544054400000000000,
#  1570233600000000000,
#  1544054400000000000,
#  1570233600000000000,
#  1544054400000000000,
#  1570233600000000000,
#  1544054400000000000,
#  1569888000000000000,
#  1569974400000000000,
#  1570060800000000000,
#  1570147200000000000,
#  1569888000000000000,
#  1569974400000000000,
#  1570147200000000000,
#  1543881600000000000,
#  1543968000000000000,
#  1544054400000000000,
#  1538352000000000000,
#  1538438400000000000,
#  1538524800000000000,
#  1538611200000000000,
#  1538697600000000000,
#  1538784000000000000,
#  1538870400000000000,
#  1538956800000000000,
#  1539043200000000000,
#  1539129600000000000,
#  1539216000000000000,
#  1539302400000000000,
#  1539388800000000000,
#  1539475200000000000,
#  1539561600000000000,
#  1539648000000000000,
#  1539734400000000000,
#  1539820800000000000,
#  1539907200000000000,
#  1539993600000000000,
#  1540080000000000000,
#  1540166400000000000,
#  1540252800000000000,
#  1540339200000000000,
#  1540425600000000000,
#  1540512000000000000,
#  1540598400000000000,
#  1540684800000000000,
#  1540771200000000000,
#  1540857600000000000,
#  1540944000000000000,
#  1541030400000000000,
#  1541116800000000000,
#  1541203200000000000,
#  1541289600000000000,
#  1541376000000000000,
#  1541462400000000000,
#  1541548800000000000,
#  1541635200000000000,
#  1541721600000000000,
#  1541808000000000000,
#  1541894400000000000,
#  1541808000000000000,
#  1541894400000000000,
#  1570838400000000000,
#  1599782400000000000,
#  1628726400000000000,
#  1541808000000000000,
#  1541894400000000000,
#  1541980800000000000,
#  1542067200000000000,
#  1542153600000000000,
#  1542240000000000000,
#  1542326400000000000,
#  1542412800000000000,
#  1542499200000000000,
#  1542585600000000000,
#  1542672000000000000,
#  1542758400000000000,
#  1542844800000000000,
#  1542931200000000000,
#  1543017600000000000,
#  1541894400000000000,
#  1541980800000000000,
#  1542067200000000000,
#  1542153600000000000,
#  1542240000000000000,
#  1542326400000000000,
#  1542412800000000000,
#  1542499200000000000,
#  1542585600000000000,
#  1542672000000000000,
#  1542758400000000000,
#  1542844800000000000,
#  1542931200000000000,
#  1543017600000000000,
#  1543104000000000000,
#  1543190400000000000,
#  1543276800000000000,
#  1543363200000000000,
#  1543449600000000000,
#  1543536000000000000,
#  1543622400000000000,
#  1543708800000000000,
#  1543795200000000000,
#  1543881600000000000,
#  1543968000000000000,
#  1544054400000000000,
#  1544140800000000000,
#  1544227200000000000,
#  1544313600000000000,
#  1544400000000000000,
#  1544486400000000000,
#  1544572800000000000,
#  1544659200000000000,
#  1544745600000000000,
#  1544832000000000000,
#  1544918400000000000]

# %%
df=pd.read_excel("customer_info.xlsm")

party_key=df["party_key"].values.tolist()
residential_country_cd=df["residential_country_cd"].values.tolist()
party_open_date=df["party_open_date"].values.tolist()
customerInfo={}
for no,i in enumerate(party_key):
    customerInfo[i]={"residential_country_cd":residential_country_cd[no],"party_open_date":party_open_date[no]}
customerInfo
# Out:
# {'A00102811119_00': {'party_open_date': 1047081600000000000,
#   'residential_country_cd': 'SG'},
#  'A0039016212_00': {'party_open_date': 920937600000000000,
#   'residential_country_cd': 'SG'},
#  'A0039031947_00': {'party_open_date': 195264000000000000,
#   'residential_country_cd': 'SG'},
#  'A0050168953_00': {'party_open_date': 920332800000000000,
#   'residential_country_cd': 'SG'},
#  'A0069021896_00': {'party_open_date': 857347200000000000,
#   'residential_country_cd': 'SG'},
#  'A0089001566_00': {'party_open_date': 825897600000000000,
#   'residential_country_cd': 'SG'},
#  'A0089028618_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'A0119042958_00': {'party_open_date': 920678400000000000,
#   'residential_country_cd': 'SG'},
#  'A01486799_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'A0149030373_00': {'party_open_date': 1047081600000000000,
#   'residential_country_cd': 'SG'},
#  'A0149030535_00': {'party_open_date': 920937600000000000,
#   'residential_country_cd': 'SG'},
#  'A0179010950_00': {'party_open_date': 195264000000000000,
#   'residential_country_cd': 'SG'},
#  'A0179039681_00': {'party_open_date': 920332800000000000,
#   'residential_country_cd': 'SG'},
#  'A0189025676_00': {'party_open_date': 857347200000000000,
#   'residential_country_cd': 'SG'},
#  'A02075733_00': {'party_open_date': 825897600000000000,
#   'residential_country_cd': 'SG'},
#  'A0209016366_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'A0220220772_00': {'party_open_date': 920678400000000000,
#   'residential_country_cd': 'SG'},
#  'A0279041668_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'A0279048611_00': {'party_open_date': 1047081600000000000,
#   'residential_country_cd': 'SG'},
#  'A03007936_00': {'party_open_date': 920937600000000000,
#   'residential_country_cd': 'SG'},
#  'A031308020_00': {'party_open_date': 195264000000000000,
#   'residential_country_cd': 'SG'},
#  'A03149625_00': {'party_open_date': 920332800000000000,
#   'residential_country_cd': 'SG'},
#  'A04062183_00': {'party_open_date': 857347200000000000,
#   'residential_country_cd': 'SG'},
#  'A0479030140_00': {'party_open_date': 825897600000000000,
#   'residential_country_cd': 'SG'},
#  'A0479033602_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'A0489030534_00': {'party_open_date': 920678400000000000,
#   'residential_country_cd': 'SG'},
#  'A0489036001_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'A0549030996_00': {'party_open_date': 1047081600000000000,
#   'residential_country_cd': 'SG'},
#  'A0549031240_00': {'party_open_date': 920937600000000000,
#   'residential_country_cd': 'SG'},
#  'A0549036820_00': {'party_open_date': 921024000000000000,
#   'residential_country_cd': 'SG'},
#  'A0659002218_00': {'party_open_date': 920332800000000000,
#   'residential_country_cd': 'SG'},
#  'A0709007015_00': {'party_open_date': 857347200000000000,
#   'residential_country_cd': 'SG'},
#  'A082951997_00': {'party_open_date': 825897600000000000,
#   'residential_country_cd': 'SG'},
#  'A10056268_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'A1069029198_00': {'party_open_date': 920678400000000000,
#   'residential_country_cd': 'SG'},
#  'A1079011365_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'A1079020275_00': {'party_open_date': 1047081600000000000,
#   'residential_country_cd': 'SG'},
#  'A1079032451_00': {'party_open_date': 920937600000000000,
#   'residential_country_cd': 'SG'},
#  'A1079035710_00': {'party_open_date': 195264000000000000,
#   'residential_country_cd': 'SG'},
#  'A14055061_00': {'party_open_date': 920332800000000000,
#   'residential_country_cd': 'SG'},
#  'A14093320_00': {'party_open_date': 857347200000000000,
#   'residential_country_cd': 'SG'},
#  'A15046643_00': {'party_open_date': 825897600000000000,
#   'residential_country_cd': 'SG'},
#  'A28050615_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'A2889002693_00': {'party_open_date': 920678400000000000,
#   'residential_country_cd': 'SG'},
#  'A2889042539_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'A2889042750_00': {'party_open_date': 1047081600000000000,
#   'residential_country_cd': 'SG'},
#  'A33001070_00': {'party_open_date': 920937600000000000,
#   'residential_country_cd': 'SG'},
#  'A33021275_00': {'party_open_date': 195264000000000000,
#   'residential_country_cd': 'SG'},
#  'A33024967_00': {'party_open_date': 920332800000000000,
#   'residential_country_cd': 'SG'},
#  'A47036577_00': {'party_open_date': 857347200000000000,
#   'residential_country_cd': 'SG'},
#  'A48020003_00': {'party_open_date': 825897600000000000,
#   'residential_country_cd': 'SG'},
#  'A48028284_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'A66011755_00': {'party_open_date': 920678400000000000,
#   'residential_country_cd': 'SG'},
#  'A74847_00': {'party_open_date': 1044576000000000000,
#   'residential_country_cd': 'SG'},
#  'AS25CS0001L_00': {'party_open_date': 857174400000000000,
#   'residential_country_cd': 'SG'},
#  'AS40300019F_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'AS61SS0117F_00': {'party_open_date': 857174400000000000,
#   'residential_country_cd': 'SG'},
#  'AS62SS0001F_00': {'party_open_date': 857174400000000000,
#   'residential_country_cd': 'SG'},
#  'AS62SS0064B_00': {'party_open_date': 510019200000000000,
#   'residential_country_cd': 'SG'},
#  'AS62SS0076K_00': {'party_open_date': 857174400000000000,
#   'residential_country_cd': 'SG'},
#  'AS74SS0006K_00': {'party_open_date': 857174400000000000,
#   'residential_country_cd': 'SG'},
#  'AS75SS0058K_00': {'party_open_date': 857174400000000000,
#   'residential_country_cd': 'SG'},
#  'AS77SS0005G_00': {'party_open_date': 510019200000000000,
#   'residential_country_cd': 'SG'},
#  'AS80SS0043C_00': {'party_open_date': 852076800000000000,
#   'residential_country_cd': 'SG'},
#  'AS83SS0025L_00': {'party_open_date': 510019200000000000,
#   'residential_country_cd': 'SG'},
#  'AS84SS0019F_00': {'party_open_date': 857174400000000000,
#   'residential_country_cd': 'SG'},
#  'AS92SS0087J_00': {'party_open_date': 510019200000000000,
#   'residential_country_cd': 'SG'},
#  'AS93SS0109A_00': {'party_open_date': 510451200000000000,
#   'residential_country_cd': 'SG'},
#  'AS96MC2029E_00': {'party_open_date': 510537600000000000,
#   'residential_country_cd': 'SG'},
#  'AS97SS0015G_00': {'party_open_date': 510624000000000000,
#   'residential_country_cd': 'SG'},
#  'AS97SS0045L_00': {'party_open_date': 510710400000000000,
#   'residential_country_cd': 'SG'},
#  'AS99SS0093K_00': {'party_open_date': 510796800000000000,
#   'residential_country_cd': 'SG'},
#  'ASALARXX100_00': {'party_open_date': 510883200000000000,
#   'residential_country_cd': 'SG'},
#  'AT08SS0246D_00': {'party_open_date': 511142400000000000,
#   'residential_country_cd': 'SG'},
#  'AT09MC0060E_00': {'party_open_date': 511228800000000000,
#   'residential_country_cd': 'SG'},
#  'AT10SS0048K_00': {'party_open_date': 511315200000000000,
#   'residential_country_cd': 'SG'},
#  'AT11CC0007D_00': {'party_open_date': 511401600000000000,
#   'residential_country_cd': 'SG'},
#  'AT11SS0212F_00': {'party_open_date': 511488000000000000,
#   'residential_country_cd': 'SG'},
#  'AT13SS0022F_00': {'party_open_date': 511056000000000000,
#   'residential_country_cd': 'SG'},
#  'AT13SS0097K_00': {'party_open_date': 511142400000000000,
#   'residential_country_cd': 'SG'},
#  'AT13SS0163B_00': {'party_open_date': 511228800000000000,
#   'residential_country_cd': 'SG'},
#  'AT13SS0172L_00': {'party_open_date': 511315200000000000,
#   'residential_country_cd': 'SG'},
#  'AT14CC0003B_00': {'party_open_date': 511401600000000000,
#   'residential_country_cd': 'SG'},
#  'AT14SS0148K_00': {'party_open_date': 511488000000000000,
#   'residential_country_cd': 'SG'},
#  'AT15MC0046J_00': {'party_open_date': 510969600000000000,
#   'residential_country_cd': 'SG'},
#  'C000151999D_00': {'party_open_date': 1551484800000000000,
#   'residential_country_cd': 'SG'},
#  'C000191958C_00': {'party_open_date': 857347200000000000,
#   'residential_country_cd': 'SG'},
#  'C000261995M_00': {'party_open_date': 825897600000000000,
#   'residential_country_cd': 'SG'},
#  'C000281995N_00': {'party_open_date': 1551484800000000000,
#   'residential_country_cd': 'SG'},
#  'C000441986N_00': {'party_open_date': 920678400000000000,
#   'residential_country_cd': 'SG'},
#  'C000591964D_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C000911963D_00': {'party_open_date': 1047081600000000000,
#   'residential_country_cd': 'SG'},
#  'C001381976N_00': {'party_open_date': 1551484800000000000,
#   'residential_country_cd': 'SG'},
#  'C001421988N_00': {'party_open_date': 195264000000000000,
#   'residential_country_cd': 'SG'},
#  'C001561968Z_00': {'party_open_date': 920332800000000000,
#   'residential_country_cd': 'SG'},
#  'C001591980N_00': {'party_open_date': 857347200000000000,
#   'residential_country_cd': 'SG'},
#  'C001911977W_00': {'party_open_date': 825897600000000000,
#   'residential_country_cd': 'SG'},
#  'C002221977N_00': {'party_open_date': 1551484800000000000,
#   'residential_country_cd': 'SG'},
#  'C004101986K_00': {'party_open_date': 1551484800000000000,
#   'residential_country_cd': 'SG'},
#  'C004412020H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C004461971K_00': {'party_open_date': 1551484800000000000,
#   'residential_country_cd': 'SG'},
#  'C004981982E_00': {'party_open_date': 1551484800000000000,
#   'residential_country_cd': 'SG'},
#  'C005241983K_00': {'party_open_date': 1551484800000000000,
#   'residential_country_cd': 'SG'},
#  'C006391971Z_00': {'party_open_date': 1551484800000000000,
#   'residential_country_cd': 'SG'},
#  'C006421977W_00': {'party_open_date': 1551484800000000000,
#   'residential_country_cd': 'SG'},
#  'C006651979D_00': {'party_open_date': 1551484800000000000,
#   'residential_country_cd': 'SG'},
#  'C007881983Z_00': {'party_open_date': 1551484800000000000,
#   'residential_country_cd': 'SG'},
#  'C007991977M_00': {'party_open_date': 1488672000000000000,
#   'residential_country_cd': 'SG'},
#  'C008071980K_00': {'party_open_date': 1488672000000000000,
#   'residential_country_cd': 'SG'},
#  'C008542003M_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C008542010G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C008551982Z_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C008551993H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C008831970D_00': {'party_open_date': 1488672000000000000,
#   'residential_country_cd': 'SG'},
#  'C009671975N_00': {'party_open_date': 1523145600000000000,
#   'residential_country_cd': 'SG'},
#  'C010261996M_00': {'party_open_date': 1520467200000000000,
#   'residential_country_cd': 'SG'},
#  'C010431985R_00': {'party_open_date': 1518048000000000000,
#   'residential_country_cd': 'SG'},
#  'C012481979H_00': {'party_open_date': 1551484800000000000,
#   'residential_country_cd': 'SG'},
#  'C012871972D_00': {'party_open_date': 1551484800000000000,
#   'residential_country_cd': 'SG'},
#  'C012952002Z_00': {'party_open_date': 1551484800000000000,
#   'residential_country_cd': 'SG'},
#  'C013181991G_00': {'party_open_date': 1551484800000000000,
#   'residential_country_cd': 'SG'},
#  'C013211993K_00': {'party_open_date': 1551484800000000000,
#   'residential_country_cd': 'SG'},
#  'C014061110C_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C014061111C_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C014062220C_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C014062222C_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C014063330C_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C014063331C_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C014063332C_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C014063333C_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C014064444C_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C014491977C_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C014581971C_00': {'party_open_date': 1047081600000000000,
#   'residential_country_cd': 'SG'},
#  'C014831981K_00': {'party_open_date': 920937600000000000,
#   'residential_country_cd': 'SG'},
#  'C015471980N_00': {'party_open_date': 195264000000000000,
#   'residential_country_cd': 'SG'},
#  'C01570111G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C01570222G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C016051974E_00': {'party_open_date': 920332800000000000,
#   'residential_country_cd': 'SG'},
#  'C016801986E_00': {'party_open_date': 857347200000000000,
#   'residential_country_cd': 'SG'},
#  'C017421985G_00': {'party_open_date': 825897600000000000,
#   'residential_country_cd': 'SG'},
#  'C019501994H_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'C019991997H_00': {'party_open_date': 920678400000000000,
#   'residential_country_cd': 'SG'},
#  'C022571975M_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C023191978H_00': {'party_open_date': 1047081600000000000,
#   'residential_country_cd': 'SG'},
#  'C024781981H_00': {'party_open_date': 920937600000000000,
#   'residential_country_cd': 'SG'},
#  'C025051990D_00': {'party_open_date': 195264000000000000,
#   'residential_country_cd': 'SG'},
#  'C025451993E_00': {'party_open_date': 920332800000000000,
#   'residential_country_cd': 'SG'},
#  'C026201978G_00': {'party_open_date': 857347200000000000,
#   'residential_country_cd': 'SG'},
#  'C026611981H_00': {'party_open_date': 825897600000000000,
#   'residential_country_cd': 'SG'},
#  'C027501981Z_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'C02790FH_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C029371992H_00': {'party_open_date': 920678400000000000,
#   'residential_country_cd': 'SG'},
#  'C029771987M_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C031221990N_00': {'party_open_date': 1047081600000000000,
#   'residential_country_cd': 'SG'},
#  'C031911982N_00': {'party_open_date': 920937600000000000,
#   'residential_country_cd': 'SG'},
#  'C033521978Z_00': {'party_open_date': 195264000000000000,
#   'residential_country_cd': 'SG'},
#  'C035381992W_00': {'party_open_date': 920332800000000000,
#   'residential_country_cd': 'SG'},
#  'C038251990H_00': {'party_open_date': 857347200000000000,
#   'residential_country_cd': 'SG'},
#  'C038701991C_00': {'party_open_date': 825897600000000000,
#   'residential_country_cd': 'SG'},
#  'C040011119_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C041001983H_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'C04120000G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C04120111G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C04120222G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C04120333G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C04120444G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C04120555G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C04120666G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C04120777G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C04130111G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C04130123G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C04130222G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C04130333G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C04130444G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C04130456G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C04130555G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C04130666G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C04130777G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C04130789G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C04130888G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C04130999G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C042521991G_00': {'party_open_date': 920678400000000000,
#   'residential_country_cd': 'SG'},
#  'C042711998G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C043711119_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C044571982H_00': {'party_open_date': 1047081600000000000,
#   'residential_country_cd': 'SG'},
#  'C046211994G_00': {'party_open_date': 920937600000000000,
#   'residential_country_cd': 'SG'},
#  'C046951981D_00': {'party_open_date': 195264000000000000,
#   'residential_country_cd': 'SG'},
#  'C047171993K_00': {'party_open_date': 920332800000000000,
#   'residential_country_cd': 'SG'},
#  'C047971980R_00': {'party_open_date': 857347200000000000,
#   'residential_country_cd': 'SG'},
#  'C052551993D_00': {'party_open_date': 825897600000000000,
#   'residential_country_cd': 'SG'},
#  'C058571991E_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'C0588S30F3A_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C061181998E_00': {'party_open_date': 920678400000000000,
#   'residential_country_cd': 'SG'},
#  'C0654S20F4A_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C073111994Z_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C074171997K_00': {'party_open_date': 1047081600000000000,
#   'residential_country_cd': 'SG'},
#  'C074421996K_00': {'party_open_date': 920937600000000000,
#   'residential_country_cd': 'SG'},
#  'C082261996R_00': {'party_open_date': 195264000000000000,
#   'residential_country_cd': 'SG'},
#  'C084511995E_00': {'party_open_date': 920332800000000000,
#   'residential_country_cd': 'SG'},
#  'C125600016G_00': {'party_open_date': 857347200000000000,
#   'residential_country_cd': 'SG'},
#  'C125600017K_00': {'party_open_date': 825897600000000000,
#   'residential_country_cd': 'SG'},
#  'C125600021N_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'C125600053W_00': {'party_open_date': 920678400000000000,
#   'residential_country_cd': 'SG'},
#  'C15046643_00': {'party_open_date': 920332800000000000,
#   'residential_country_cd': 'SG'},
#  'C179762011E_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C179762016D_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C179772008R_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C179772009Z_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C201227388N_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C29964200C_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C315012019K_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C315032019M_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C340062019C_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C34119000D_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C343000011H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C343000012H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C343000021H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C343000022H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C343000031H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C343000032H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C343000033H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C343000034H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C343000041H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C343000042H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C343000051H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C343000061H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C343000071H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C343000081H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C343000091H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C343000101H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C343000111H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C343000222H_00': {'party_open_date': 857347200000000000,
#   'residential_country_cd': 'SG'},
#  'C352222222C_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'C353222220C_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'C353222221C_00': {'party_open_date': 920678400000000000,
#   'residential_country_cd': 'SG'},
#  'C353222223C_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C353222224C_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'C353222225C_00': {'party_open_date': 920678400000000000,
#   'residential_country_cd': 'SG'},
#  'C353222226C_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C353222227C_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'C353222228C_00': {'party_open_date': 920678400000000000,
#   'residential_country_cd': 'SG'},
#  'C353222229C_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C355111110C_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C355111111C_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C3560001D_00': {'party_open_date': 920678400000000000,
#   'residential_country_cd': 'SG'},
#  'C3560002D_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C3560003D_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'C3560004D_00': {'party_open_date': 920678400000000000,
#   'residential_country_cd': 'SG'},
#  'C3560005D_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C3560006D_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'C359600016G_00': {'party_open_date': 857347200000000000,
#   'residential_country_cd': 'SG'},
#  'C36000001C_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'C36000002C_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'C36000003C_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'C3710001N_00': {'party_open_date': 826070400000000000,
#   'residential_country_cd': 'SG'},
#  'C3720000D_00': {'party_open_date': 826070400000000000,
#   'residential_country_cd': 'SG'},
#  'C3720001D_00': {'party_open_date': 826070400000000000,
#   'residential_country_cd': 'SG'},
#  'C3720002D_00': {'party_open_date': 826070400000000000,
#   'residential_country_cd': 'SG'},
#  'C396302019D_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C405000010H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C405000011H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C405000022H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C405000330H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C405000331H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C405000440H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C405000550H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C405000551H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C405000660H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C405000770H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C405000771H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C405000880H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C405000999H_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C428622019R_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C546951981D_00': {'party_open_date': 195264000000000000,
#   'residential_country_cd': 'SG'},
#  'C547171993K_00': {'party_open_date': 920332800000000000,
#   'residential_country_cd': 'SG'},
#  'C547971980R_00': {'party_open_date': 857347200000000000,
#   'residential_country_cd': 'SG'},
#  'C552551993D_00': {'party_open_date': 825897600000000000,
#   'residential_country_cd': 'SG'},
#  'C558571991E_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'C561181998E_00': {'party_open_date': 920678400000000000,
#   'residential_country_cd': 'SG'},
#  'C573111994Z_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C574171997K_00': {'party_open_date': 1047081600000000000,
#   'residential_country_cd': 'SG'},
#  'C574421996K_00': {'party_open_date': 920937600000000000,
#   'residential_country_cd': 'SG'},
#  'C582261996R_00': {'party_open_date': 195264000000000000,
#   'residential_country_cd': 'SG'},
#  'C584511995E_00': {'party_open_date': 920332800000000000,
#   'residential_country_cd': 'SG'},
#  'C831911982N_00': {'party_open_date': 920937600000000000,
#   'residential_country_cd': 'SG'},
#  'C833521978Z_00': {'party_open_date': 195264000000000000,
#   'residential_country_cd': 'SG'},
#  'C835381992W_00': {'party_open_date': 920332800000000000,
#   'residential_country_cd': 'SG'},
#  'C838251990H_00': {'party_open_date': 857347200000000000,
#   'residential_country_cd': 'SG'},
#  'C838701991C_00': {'party_open_date': 825897600000000000,
#   'residential_country_cd': 'SG'},
#  'C841001983H_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'C842521991G_00': {'party_open_date': 920678400000000000,
#   'residential_country_cd': 'SG'},
#  'C842711998G_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C844571982H_00': {'party_open_date': 1047081600000000000,
#   'residential_country_cd': 'SG'},
#  'C846211994G_00': {'party_open_date': 920937600000000000,
#   'residential_country_cd': 'SG'},
#  'C846951981D_00': {'party_open_date': 195264000000000000,
#   'residential_country_cd': 'SG'},
#  'C847171993K_00': {'party_open_date': 920332800000000000,
#   'residential_country_cd': 'SG'},
#  'C847971980R_00': {'party_open_date': 857347200000000000,
#   'residential_country_cd': 'SG'},
#  'C852551993D_00': {'party_open_date': 825897600000000000,
#   'residential_country_cd': 'SG'},
#  'C858571991E_00': {'party_open_date': 825984000000000000,
#   'residential_country_cd': 'SG'},
#  'C861181998E_00': {'party_open_date': 920678400000000000,
#   'residential_country_cd': 'SG'},
#  'C873111994Z_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'C874171997K_00': {'party_open_date': 1047081600000000000,
#   'residential_country_cd': 'SG'},
#  'C874421996K_00': {'party_open_date': 920937600000000000,
#   'residential_country_cd': 'SG'},
#  'C882261996R_00': {'party_open_date': 195264000000000000,
#   'residential_country_cd': 'SG'},
#  'C884511995E_00': {'party_open_date': 920332800000000000,
#   'residential_country_cd': 'SG'},
#  'D468914C_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'D47043000_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'DS109962_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'DS141822_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'DS212766_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'DS249944_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'GTANZTZTX_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'GUNITARXVIII_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'M0019325_00': {'party_open_date': 337219200000000000,
#   'residential_country_cd': 'MY'},
#  'M002157103_00': {'party_open_date': 496972800000000000,
#   'residential_country_cd': 'MY'},
#  'M00393723_00': {'party_open_date': 253929600000000000,
#   'residential_country_cd': 'MY'},
#  'M0100_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'M01011986_00': {'party_open_date': 504921600000000000,
#   'residential_country_cd': 'MY'},
#  'M010514005_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M010524005_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M010544005_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M0105_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'M010614005_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M010624005_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M010644005_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M0106_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'M010714005_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M010724005_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M010744005_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M0107_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'M010814005_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M010824005_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M010844004_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M010844005_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M0108_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'M010914005_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M01092011_00': {'party_open_date': 694224000000000000,
#   'residential_country_cd': 'MY'},
#  'M010924005_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M010944004_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M010944005_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M0109_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'M0110_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'M0111_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'M0116_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'M0117_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'M0118_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'M0119_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'M0120_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'M0121_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'M0122_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'M03062010_00': {'party_open_date': 618105600000000000,
#   'residential_country_cd': 'MY'},
#  'M030919830309_00': {'party_open_date': 915148800000000000,
#   'residential_country_cd': nan},
#  'M03102011_00': {'party_open_date': 570844800000000000,
#   'residential_country_cd': 'MY'},
#  'M031229788_00': {'party_open_date': 496972800000000000,
#   'residential_country_cd': 'MY'},
#  'M03165842_00': {'party_open_date': 496972800000000000,
#   'residential_country_cd': 'MY'},
#  'M031689895_00': {'party_open_date': 339206400000000000,
#   'residential_country_cd': 'MY'},
#  'M037982045_00': {'party_open_date': 496972800000000000,
#   'residential_country_cd': 'MY'},
#  'M03985761_00': {'party_open_date': 518400000000000000,
#   'residential_country_cd': 'MY'},
#  'M0400123R_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'US'},
#  'M04021988_00': {'party_open_date': 570931200000000000,
#   'residential_country_cd': 'MY'},
#  'M040919830309_00': {'party_open_date': -838598400000000000,
#   'residential_country_cd': 'SG'},
#  'M0437123R_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'US'},
#  'M0437456R_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'US'},
#  'M0493629_00': {'party_open_date': 915148800000000000,
#   'residential_country_cd': 'MY'},
#  'M050919830309_00': {'party_open_date': -838598400000000000,
#   'residential_country_cd': 'SG'},
#  'M06082008_00': {'party_open_date': 321667200000000000,
#   'residential_country_cd': 'MY'},
#  'M06411781_00': {'party_open_date': 473385600000000000,
#   'residential_country_cd': 'MY'},
#  'M06487950_00': {'party_open_date': 496972800000000000,
#   'residential_country_cd': 'MY'},
#  'M06798003_00': {'party_open_date': 496972800000000000,
#   'residential_country_cd': 'MY'},
#  'M0722057_00': {'party_open_date': -710380800000000000,
#   'residential_country_cd': 'MY'},
#  'M0737567_00': {'party_open_date': -774230400000000000,
#   'residential_country_cd': 'MY'},
#  'M08015779_00': {'party_open_date': 0, 'residential_country_cd': 'MY'},
#  'M08016615_00': {'party_open_date': 345340800000000000,
#   'residential_country_cd': 'MY'},
#  'M0801999_00': {'party_open_date': 485136000000000000,
#   'residential_country_cd': 'MY'},
#  'M0802667_00': {'party_open_date': 345340800000000000,
#   'residential_country_cd': 'MY'},
#  'M09706452_00': {'party_open_date': 496972800000000000,
#   'residential_country_cd': 'MY'},
#  'M09760684_00': {'party_open_date': 496972800000000000,
#   'residential_country_cd': 'MY'},
#  'M0987654321_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'M0989009098_00': {'party_open_date': 621302400000000000,
#   'residential_country_cd': 'MY'},
#  'M1000009_00': {'party_open_date': 339984000000000000,
#   'residential_country_cd': 'MY'},
#  'M100215454_00': {'party_open_date': 496972800000000000,
#   'residential_country_cd': 'MY'},
#  'M10086FE_00': {'party_open_date': 128995200000000000,
#   'residential_country_cd': 'MY'},
#  'M10544004_00': {'party_open_date': -142128000000000000,
#   'residential_country_cd': 'MY'},
#  'M1063685_00': {'party_open_date': 915148800000000000,
#   'residential_country_cd': 'MY'},
#  'M10987601_00': {'party_open_date': -285811200000000000,
#   'residential_country_cd': 'MY'},
#  'M10987602_00': {'party_open_date': -285811200000000000,
#   'residential_country_cd': 'MY'},
#  'M10987604_00': {'party_open_date': -285811200000000000,
#   'residential_country_cd': 'MY'},
#  'M10987605_00': {'party_open_date': -285811200000000000,
#   'residential_country_cd': 'MY'},
#  'M10987610_00': {'party_open_date': -285811200000000000,
#   'residential_country_cd': 'MY'},
#  'M10987612_00': {'party_open_date': -285811200000000000,
#   'residential_country_cd': 'MY'},
#  'M10987613_00': {'party_open_date': -285811200000000000,
#   'residential_country_cd': 'MY'},
#  'M1104105_00': {'party_open_date': 342748800000000000,
#   'residential_country_cd': 'MY'},
#  'M1104125_00': {'party_open_date': 342748800000000000,
#   'residential_country_cd': 'MY'},
#  'M1104164_00': {'party_open_date': 342748800000000000,
#   'residential_country_cd': 'MY'},
#  'M1104165_00': {'party_open_date': 342748800000000000,
#   'residential_country_cd': 'MY'},
#  'M1104181_00': {'party_open_date': 342748800000000000,
#   'residential_country_cd': 'MY'},
#  'M1104200_00': {'party_open_date': 342748800000000000,
#   'residential_country_cd': 'MY'},
#  'M1104223_00': {'party_open_date': 342748800000000000,
#   'residential_country_cd': 'MY'},
#  'M1104246_00': {'party_open_date': 342748800000000000,
#   'residential_country_cd': 'MY'},
#  'M1104250_00': {'party_open_date': 342748800000000000,
#   'residential_country_cd': 'MY'},
#  'M1104252_00': {'party_open_date': 342748800000000000,
#   'residential_country_cd': 'MY'},
#  'M1104265_00': {'party_open_date': 342748800000000000,
#   'residential_country_cd': 'MY'},
#  'M1104750_00': {'party_open_date': 252460800000000000,
#   'residential_country_cd': 'MY'},
#  'M11102101_00': {'party_open_date': 299635200000000000,
#   'residential_country_cd': 'MY'},
#  'M11102102_00': {'party_open_date': 299635200000000000,
#   'residential_country_cd': 'MY'},
#  'M11102105_00': {'party_open_date': 299635200000000000,
#   'residential_country_cd': 'MY'},
#  'M1112012_00': {'party_open_date': 567993600000000000,
#   'residential_country_cd': 'MY'},
#  'M11223345B_00': {'party_open_date': 393033600000000000,
#   'residential_country_cd': 'MY'},
#  'M112233_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'M1122345A_00': {'party_open_date': 393033600000000000,
#   'residential_country_cd': 'MY'},
#  'M11234570_00': {'party_open_date': 662688000000000000,
#   'residential_country_cd': 'MY'},
#  'M1133445A_00': {'party_open_date': 393033600000000000,
#   'residential_country_cd': 'MY'},
#  'M11688FN_00': {'party_open_date': 318297600000000000,
#   'residential_country_cd': 'MY'},
#  'M11699FN_00': {'party_open_date': 337219200000000000,
#   'residential_country_cd': 'MY'},
#  'M1201002_00': {'party_open_date': 316396800000000000,
#   'residential_country_cd': 'MY'},
#  'M1201805_00': {'party_open_date': 327110400000000000,
#   'residential_country_cd': 'MY'},
#  'M1201807_00': {'party_open_date': 339984000000000000,
#   'residential_country_cd': 'MY'},
#  'M1201825_00': {'party_open_date': 718675200000000000,
#   'residential_country_cd': 'MY'},
#  'M1201826_00': {'party_open_date': 687052800000000000,
#   'residential_country_cd': 'MY'},
#  'M1201835_00': {'party_open_date': 718675200000000000,
#   'residential_country_cd': 'MY'},
#  'M1201842_00': {'party_open_date': 718675200000000000,
#   'residential_country_cd': 'MY'},
#  'M1201867_00': {'party_open_date': 718675200000000000,
#   'residential_country_cd': 'MY'},
#  'M1202003_00': {'party_open_date': 0, 'residential_country_cd': 'MY'},
#  'M1202007_00': {'party_open_date': 0, 'residential_country_cd': 'MY'},
#  'M1202008_00': {'party_open_date': 0, 'residential_country_cd': 'MY'},
#  'M1202009_00': {'party_open_date': 0, 'residential_country_cd': 'MY'},
#  'M1202010_00': {'party_open_date': 0, 'residential_country_cd': 'MY'},
#  'M1204001_00': {'party_open_date': 0, 'residential_country_cd': 'MY'},
#  'M1204002_00': {'party_open_date': 0, 'residential_country_cd': 'MY'},
#  'M1204004_00': {'party_open_date': 0, 'residential_country_cd': 'MY'},
#  'M121212H_00': {'party_open_date': 422928000000000000,
#   'residential_country_cd': nan},
#  'M121397484_00': {'party_open_date': 496972800000000000,
#   'residential_country_cd': 'MY'},
#  'M1223669847_00': {'party_open_date': 295488000000000000,
#   'residential_country_cd': 'MY'},
#  'M1223929A_00': {'party_open_date': 45014400000000000,
#   'residential_country_cd': 'MY'},
#  'M1224345235_00': {'party_open_date': 597888000000000000,
#   'residential_country_cd': 'MY'},
#  'M12345676_00': {'party_open_date': 536457600000000000,
#   'residential_country_cd': 'MY'},
#  'M1234567890_00': {'party_open_date': 408499200000000000,
#   'residential_country_cd': 'MY'},
#  'M123456789_00': {'party_open_date': 154137600000000000,
#   'residential_country_cd': 'MY'},
#  'M12345678_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'M1234567_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'M123456_00': {'party_open_date': 573350400000000000,
#   'residential_country_cd': 'MY'},
#  'M12345_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'M12354445H_00': {'party_open_date': 422928000000000000,
#   'residential_country_cd': nan},
#  'M123607985_00': {'party_open_date': 150595200000000000,
#   'residential_country_cd': 'MY'},
#  'M1237899_00': {'party_open_date': 626745600000000000,
#   'residential_country_cd': 'MY'},
#  'M12412FD_00': {'party_open_date': 1657843200000000000,
#   'residential_country_cd': 'MY'},
#  'M12453671_00': {'party_open_date': 150595200000000000,
#   'residential_country_cd': 'MY'},
#  'M124914658_00': {'party_open_date': 275443200000000000,
#   'residential_country_cd': 'MY'},
#  'M12497860_00': {'party_open_date': 220320000000000000,
#   'residential_country_cd': 'MY'},
#  'M12544004_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'M1254542354_00': {'party_open_date': 282268800000000000,
#   'residential_country_cd': 'MY'},
#  'M12546_00': {'party_open_date': 295488000000000000,
#   'residential_country_cd': 'MY'},
#  'M12978FW_00': {'party_open_date': 80006400000000000,
#   'residential_country_cd': 'MY'},
#  'M12979FH_00': {'party_open_date': 80006400000000000,
#   'residential_country_cd': 'MY'},
#  'M12980FD_00': {'party_open_date': -153878400000000000,
#   'residential_country_cd': 'MY'},
#  'M12981FN_00': {'party_open_date': 915148800000000000,
#   'residential_country_cd': nan},
#  'M13392FG_00': {'party_open_date': 80006400000000000,
#   'residential_country_cd': 'MY'},
#  'M13393FW_00': {'party_open_date': 80006400000000000,
#   'residential_country_cd': 'MY'},
#  'M13434FG_00': {'party_open_date': -681004800000000000,
#   'residential_country_cd': 'MY'},
#  'M13435FW_00': {'party_open_date': -681004800000000000,
#   'residential_country_cd': 'MY'},
#  'M13436FH_00': {'party_open_date': -681004800000000000,
#   'residential_country_cd': 'MY'},
#  'M13437FZ_00': {'party_open_date': -681004800000000000,
#   'residential_country_cd': 'MY'},
#  'M13438FK_00': {'party_open_date': -681004800000000000,
#   'residential_country_cd': 'MY'},
#  'M13490FM_00': {'party_open_date': 157766400000000000,
#   'residential_country_cd': 'MY'},
#  'M13491FD_00': {'party_open_date': 157766400000000000,
#   'residential_country_cd': 'MY'},
#  'M13492FD_00': {'party_open_date': 157766400000000000,
#   'residential_country_cd': 'MY'},
#  'M13493FD_00': {'party_open_date': 157766400000000000,
#   'residential_country_cd': 'MY'},
#  'M13569FN_00': {'party_open_date': 326937600000000000,
#   'residential_country_cd': 'MY'},
#  'M13570FH_00': {'party_open_date': 326937600000000000,
#   'residential_country_cd': 'MY'},
#  'M13571FZ_00': {'party_open_date': 326937600000000000,
#   'residential_country_cd': 'MY'},
#  'M13588AX_00': {'party_open_date': 326937600000000000,
#   'residential_country_cd': 'MY'},
#  'M13625561_00': {'party_open_date': 0, 'residential_country_cd': 'MY'},
#  'M1405566545_00': {'party_open_date': 473385600000000000,
#   'residential_country_cd': 'MY'},
#  'M143369_00': {'party_open_date': 295488000000000000,
#   'residential_country_cd': 'MY'},
#  'M14741134_00': {'party_open_date': 329875200000000000,
#   'residential_country_cd': 'MY'},
#  'M15544004_00': {'party_open_date': 473385600000000000,
#   'residential_country_cd': 'MY'},
#  'M15951134_00': {'party_open_date': 174960000000000000,
#   'residential_country_cd': 'MY'},
#  'M15978652_00': {'party_open_date': 157766400000000000,
#   'residential_country_cd': 'MY'},
#  'M160520011_00': {'party_open_date': 392169600000000000,
#   'residential_country_cd': 'MY'},
#  'M160520012_00': {'party_open_date': 392169600000000000,
#   'residential_country_cd': 'MY'},
#  'M160520014_00': {'party_open_date': 392169600000000000,
#   'residential_country_cd': 'MY'},
#  'M160520015_00': {'party_open_date': 392169600000000000,
#   'residential_country_cd': 'MY'},
#  'M160520016_00': {'party_open_date': 392169600000000000,
#   'residential_country_cd': 'MY'},
#  'M160520017_00': {'party_open_date': 392169600000000000,
#   'residential_country_cd': 'MY'},
#  'M160520018_00': {'party_open_date': 392169600000000000,
#   'residential_country_cd': 'MY'},
#  'M160520019_00': {'party_open_date': 392169600000000000,
#   'residential_country_cd': 'MY'},
#  'M160520111_00': {'party_open_date': 327024000000000000,
#   'residential_country_cd': 'MY'},
#  'M160520112_00': {'party_open_date': 361670400000000000,
#   'residential_country_cd': 'MY'},
#  'M160520113_00': {'party_open_date': 269654400000000000,
#   'residential_country_cd': 'MY'},
#  'M160520114_00': {'party_open_date': 431395200000000000,
#   'residential_country_cd': 'MY'},
#  'M160520115_00': {'party_open_date': 389145600000000000,
#   'residential_country_cd': 'MY'},
#  'M160520116_00': {'party_open_date': 484012800000000000,
#   'residential_country_cd': 'MY'},
#  'M160520117_00': {'party_open_date': 423619200000000000,
#   'residential_country_cd': 'MY'},
#  'M160520118_00': {'party_open_date': 297302400000000000,
#   'residential_country_cd': 'MY'},
#  'M160520119_00': {'party_open_date': 229996800000000000,
#   'residential_country_cd': 'MY'},
#  'M16082011_00': {'party_open_date': 518400000000000000,
#   'residential_country_cd': 'MY'},
#  'M1626801_00': {'party_open_date': 915148800000000000,
#   'residential_country_cd': 'MY'},
#  'M16428_00': {'party_open_date': -49939200000000000,
#   'residential_country_cd': 'MY'},
#  'M17544004_00': {'party_open_date': 473385600000000000,
#   'residential_country_cd': 'MY'},
#  'M180520111_00': {'party_open_date': -22550400000000000,
#   'residential_country_cd': 'MY'},
#  'M18465134_00': {'party_open_date': -51926400000000000,
#   'residential_country_cd': 'MY'},
#  'M200002_00': {'party_open_date': 367459200000000000,
#   'residential_country_cd': 'MY'},
#  'M200003_00': {'party_open_date': 367459200000000000,
#   'residential_country_cd': 'MY'},
#  'M20110304_00': {'party_open_date': 47433600000000000,
#   'residential_country_cd': 'MY'},
#  'M20110305_00': {'party_open_date': 50198400000000000,
#   'residential_country_cd': 'MY'},
#  'M20110306_00': {'party_open_date': 43891200000000000,
#   'residential_country_cd': 'MY'},
#  'M20110307_00': {'party_open_date': 33177600000000000,
#   'residential_country_cd': 'MY'},
#  'M20110308_00': {'party_open_date': 42076800000000000,
#   'residential_country_cd': 'MY'},
#  'M860520015_00': {'party_open_date': 920332800000000000,
#   'residential_country_cd': 'SG'},
#  'M87198753H_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M87698753D_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M87698754F_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M87698757J_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M87698758K_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M88698753V_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M88698754B_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M88698757M_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M88698758Q_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M89698753Y_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M89698754U_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M89698757P_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'M89698758A_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'P18FV08030_01': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'PBM74KH953_01': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'PKJ0734171_01': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'PT175711_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'R00742500K_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'R21061800X_00': {'party_open_date': 1047081600000000000,
#   'residential_country_cd': 'SG'},
#  'R53402322C_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'R53402364M_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'R53402365K_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'R53402399A_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'S0031691A_00': {'party_open_date': -318297600000000000,
#   'residential_country_cd': 'SG'},
#  'S0031951A_00': {'party_open_date': 915148800000000000,
#   'residential_country_cd': 'SG'},
#  'S0031985F_00': {'party_open_date': -693360000000000000,
#   'residential_country_cd': 'SG'},
#  'S0031996A_00': {'party_open_date': -666144000000000000,
#   'residential_country_cd': 'SG'},
#  'S0032093E_00': {'party_open_date': -508809600000000000,
#   'residential_country_cd': 'SG'},
#  'S0032127C_00': {'party_open_date': -482371200000000000,
#   'residential_country_cd': 'SG'},
#  'S0032213Z_00': {'party_open_date': -542851200000000000,
#   'residential_country_cd': 'SG'},
#  'S0032506F_00': {'party_open_date': -601084800000000000,
#   'residential_country_cd': 'SG'},
#  'S0033400F_00': {'party_open_date': -615600000000000000,
#   'residential_country_cd': 'SG'},
#  'S0033413H_00': {'party_open_date': -603244800000000000,
#   'residential_country_cd': 'SG'},
#  'S0033467G_00': {'party_open_date': -507340800000000000,
#   'residential_country_cd': 'SG'},
#  'S0033470G_00': {'party_open_date': -509241600000000000,
#   'residential_country_cd': 'SG'},
#  'S0033527D_00': {'party_open_date': -653184000000000000,
#   'residential_country_cd': 'SG'},
#  'S0033673D_00': {'party_open_date': -530668800000000000,
#   'residential_country_cd': 'SG'},
#  'S0033901F_00': {'party_open_date': -1015545600000000000,
#   'residential_country_cd': 'SG'},
#  'S0034076F_00': {'party_open_date': -552182400000000000,
#   'residential_country_cd': 'SG'},
#  'S0034119C_00': {'party_open_date': -606355200000000000,
#   'residential_country_cd': 'SG'},
#  'S0034358G_00': {'party_open_date': -529459200000000000,
#   'residential_country_cd': 'SG'},
#  'S0034411G_00': {'party_open_date': -530150400000000000,
#   'residential_country_cd': 'SG'},
#  'S0035195D_00': {'party_open_date': -285292800000000000,
#   'residential_country_cd': 'SG'},
#  'S0035322A_00': {'party_open_date': -155779200000000000,
#   'residential_country_cd': 'SG'},
#  'S0035345J_00': {'party_open_date': -88214400000000000,
#   'residential_country_cd': 'SG'},
#  'S0035397C_00': {'party_open_date': -165283200000000000,
#   'residential_country_cd': 'SG'},
#  'S0035457J_00': {'party_open_date': -577411200000000000,
#   'residential_country_cd': 'SG'},
#  'S0035463E_00': {'party_open_date': -408499200000000000,
#   'residential_country_cd': 'SG'},
#  'S0035550Z_00': {'party_open_date': -561340800000000000,
#   'residential_country_cd': 'SG'},
#  'S0035597F_00': {'party_open_date': -505267200000000000,
#   'residential_country_cd': 'SG'},
#  'S0035606I_00': {'party_open_date': -607564800000000000,
#   'residential_country_cd': 'SG'},
#  'S0035749I_00': {'party_open_date': -476409600000000000,
#   'residential_country_cd': 'SG'},
#  'S0035869Z_00': {'party_open_date': -76550400000000000,
#   'residential_country_cd': 'SG'},
#  'S0035918A_00': {'party_open_date': 473385600000000000,
#   'residential_country_cd': 'SG'},
#  'S0036415J_00': {'party_open_date': -266976000000000000,
#   'residential_country_cd': 'SG'},
#  'S0036469Z_00': {'party_open_date': -939513600000000000,
#   'residential_country_cd': 'SG'},
#  'S0037164E_00': {'party_open_date': -347328000000000000,
#   'residential_country_cd': 'SG'},
#  'S0037181E_00': {'party_open_date': -597283200000000000,
#   'residential_country_cd': 'SG'},
#  'S0037543H_00': {'party_open_date': -283392000000000000,
#   'residential_country_cd': 'SG'},
#  'S0037708B_00': {'party_open_date': 783648000000000000,
#   'residential_country_cd': 'MM'},
#  'S0037709J_00': {'party_open_date': -278208000000000000,
#   'residential_country_cd': 'SG'},
#  'S0037970J_00': {'party_open_date': -385344000000000000,
#   'residential_country_cd': 'MY'},
#  'S0038095D_00': {'party_open_date': -942192000000000000,
#   'residential_country_cd': 'SG'},
#  'S0038195J_00': {'party_open_date': -544924800000000000,
#   'residential_country_cd': 'SG'},
#  'S0038482H_00': {'party_open_date': -497232000000000000,
#   'residential_country_cd': 'SG'},
#  'S0038488G_00': {'party_open_date': -65664000000000000,
#   'residential_country_cd': 'MM'},
#  'S0038628F_00': {'party_open_date': -326073600000000000,
#   'residential_country_cd': 'ID'},
#  'S0038677D_00': {'party_open_date': 510019200000000000,
#   'residential_country_cd': 'SG'},
#  'S0038766E_00': {'party_open_date': -676425600000000000,
#   'residential_country_cd': 'SG'},
#  'S0038913G_00': {'party_open_date': -841708800000000000,
#   'residential_country_cd': 'SG'},
#  'S1000017Z': {'party_open_date': 0, 'residential_country_cd': 'MY'},
#  'S1000018Z': {'party_open_date': 0, 'residential_country_cd': 'MY'},
#  'S1111111G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S1111112G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S1111113G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S1111114G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S1111115G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S1111116G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S1111117G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S1111118G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S1111119G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S1111120G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S1111121G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S1111122G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S1111123G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S1111124G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S1111125G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S1111126G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S1111127G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S1111128G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S1111129G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S1111130G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S1659194G_00': {'party_open_date': 315532800000000000,
#   'residential_country_cd': 'MY'},
#  'S199900011F_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S3720000F_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S3720001F_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S3720002F_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S7038933G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S7138923G_00': {'party_open_date': -839462400000000000,
#   'residential_country_cd': 'SG'},
#  'S7238923G_00': {'party_open_date': -839376000000000000,
#   'residential_country_cd': 'SG'},
#  'S7338923G_00': {'party_open_date': -839289600000000000,
#   'residential_country_cd': 'SG'},
#  'S7438923G_00': {'party_open_date': -839203200000000000,
#   'residential_country_cd': 'SG'},
#  'S7538923G_00': {'party_open_date': -839116800000000000,
#   'residential_country_cd': 'SG'},
#  'S7638923G_00': {'party_open_date': -839030400000000000,
#   'residential_country_cd': 'SG'},
#  'S7738923G_00': {'party_open_date': -838944000000000000,
#   'residential_country_cd': 'SG'},
#  'S7838923G_00': {'party_open_date': -838857600000000000,
#   'residential_country_cd': 'SG'},
#  'S7938923G_00': {'party_open_date': -838771200000000000,
#   'residential_country_cd': 'SG'},
#  'S8138923G_00': {'party_open_date': -840672000000000000,
#   'residential_country_cd': 'SG'},
#  'S8238923G_00': {'party_open_date': -840585600000000000,
#   'residential_country_cd': 'SG'},
#  'S8338923G_00': {'party_open_date': -840499200000000000,
#   'residential_country_cd': 'SG'},
#  'S8438923G_00': {'party_open_date': -840412800000000000,
#   'residential_country_cd': 'SG'},
#  'S87198750D_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S87198751F_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S87198752G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S87698755G_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S87698756H_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S87698759L_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S88698750Z_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S88698751X_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S88698752C_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S88698755N_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S88698756N_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S88698759W_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S89698750E_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S89698751R_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S89698752T_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S89698755I_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S89698756O_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S89698759S_00': {'party_open_date': -838684800000000000,
#   'residential_country_cd': 'SG'},
#  'S9038913G_00': {'party_open_date': -841622400000000000,
#   'residential_country_cd': 'SG'},
#  'S9038923G_00': {'party_open_date': -840758400000000000,
#   'residential_country_cd': 'SG'},
#  'S9038933G_00': {'party_open_date': -839894400000000000,
#   'residential_country_cd': 'SG'},
#  'S9138913G_00': {'party_open_date': -841536000000000000,
#   'residential_country_cd': 'SG'},
#  'S9138923G_00': {'party_open_date': -840672000000000000,
#   'residential_country_cd': 'SG'},
#  'S9138933G_00': {'party_open_date': -839808000000000000,
#   'residential_country_cd': 'SG'},
#  'S9238913G_00': {'party_open_date': -841449600000000000,
#   'residential_country_cd': 'SG'},
#  'S9238923G_00': {'party_open_date': -840585600000000000,
#   'residential_country_cd': 'SG'},
#  'S9238933G_00': {'party_open_date': -839721600000000000,
#   'residential_country_cd': 'SG'},
#  'S9338913G_00': {'party_open_date': -841363200000000000,
#   'residential_country_cd': 'SG'},
#  'S9338923G_00': {'party_open_date': -840499200000000000,
#   'residential_country_cd': 'SG'},
#  'S9338933G_00': {'party_open_date': -839635200000000000,
#   'residential_country_cd': 'SG'},
#  'S9438913G_00': {'party_open_date': -841276800000000000,
#   'residential_country_cd': 'SG'},
#  'S9438923G_00': {'party_open_date': -840412800000000000,
#   'residential_country_cd': 'SG'},
#  'S9438933G_00': {'party_open_date': -839548800000000000,
#   'residential_country_cd': 'SG'},
#  'S9538913G_00': {'party_open_date': -841190400000000000,
#   'residential_country_cd': 'SG'},
#  'S9538923G_00': {'party_open_date': -840326400000000000,
#   'residential_country_cd': 'SG'},
#  'S9638913G_00': {'party_open_date': -841104000000000000,
#   'residential_country_cd': 'SG'},
#  'S9638923G_00': {'party_open_date': -840240000000000000,
#   'residential_country_cd': 'SG'},
#  'S9738913G_00': {'party_open_date': -841017600000000000,
#   'residential_country_cd': 'SG'},
#  'S9738923G_00': {'party_open_date': -840153600000000000,
#   'residential_country_cd': 'SG'},
#  'S9838913G_00': {'party_open_date': -840931200000000000,
#   'residential_country_cd': 'SG'},
#  'S9838923G_00': {'party_open_date': -840067200000000000,
#   'residential_country_cd': 'SG'},
#  'S9938913G_00': {'party_open_date': -840844800000000000,
#   'residential_country_cd': 'SG'},
#  'S9938923G_00': {'party_open_date': -839980800000000000,
#   'residential_country_cd': 'SG'},
#  'T09CC0004J_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'X0019017823_00': {'party_open_date': 920332800000000000,
#   'residential_country_cd': 'BM'},
#  'X123992_00': {'party_open_date': 857347200000000000,
#   'residential_country_cd': 'HK'},
#  'X199900011D_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'X287100011D_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'X35300011D_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'X35300012D_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'X35300013D_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'X35300014D_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'X35300015D_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'X35300016D_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'X35300017D_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'X35300018D_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'X35300019D_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'X35300022D_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'X35300033D_00': {'party_open_date': 1046995200000000000,
#   'residential_country_cd': 'SG'},
#  'X420739_00': {'party_open_date': 1551657600000000000,
#   'residential_country_cd': 'MY'},
#  nan: {'party_open_date': None, 'residential_country_cd': nan}}

# %%
df=pd.read_excel("tarsactions.xlsm")
dic={}
for x in accountKeys:
  # account_key="CASP_D00630169780019"
  account_key=x
  df1=df.loc[df[' Account_Key']==account_key]
  if (len(df1)>10):
      customerCountry=customerInfo[accountInfo[account_key]["primary_party_key"]]["residential_country_cd"]
      if customerCountry in highriskcountries:
          # print("High risk at case H1")
          dic[x]="High risk at case H1"
      else:
          # print("No risk at case H1")
          dic[x]="No risk at case H1"
  else:
      # print("No risk at case H1")
      dic[x]="No risk at case H1"


  df2=df1.loc[df[' Transaction Type']=="INN"]
  if sum(df2[" Transaction_Amount(in $)"])>1000:
      # print("High risk at case H2")
      dic[x]="High risk at case H2"
  elif sum(df2[" Transaction_Amount(in $)"])<1000 and sum(df2[" Transaction_Amount(in $)"])>600:
    # print("low risk at case M2")
    dic[x]="High risk at case M2"
  elif sum(df2[" Transaction_Amount(in $)"])<600:
    # print("low risk at case L2")
    dic[x]="low risk at case L2"
  else:
      # print("no risk at case H2")
      dic[x]="no risk at case H2"

  df2=df1.loc[df[' Transaction Type']=="OUT"]
  if sum(df2[" Transaction_Amount(in $)"])>800:
      # print("High risk at case H3")
      dic[x]="High risk at case H3"
  elif sum(df2[" Transaction_Amount(in $)"])<800 and sum(df2[" Transaction_Amount(in $)"])>500:
    # print("High risk at case M3")
    dic[x]="High risk at case M3"
  elif sum(df2[" Transaction_Amount(in $)"])<500:
    # print("High risk at case L3")
    dic[x]="High risk at case L3"
  else:
      # print("no risk at case H3")
      dic[x]="no risk at case H3"

# %%
dic
# Out:
# {'ANSP_34300169780270': 'High risk at case L3',
#  'AQSP_34300169780273': 'High risk at case L3',
#  'AQSP_D34300169780274': 'High risk at case L3',
#  'CASP_D00406002222111': 'High risk at case L3',
#  'CASP_D00406002222222': 'High risk at case L3',
#  'CASP_D00406002222333': 'High risk at case L3',
#  'CASP_D00406002222444': 'High risk at case L3',
#  'CASP_D00406002222555': 'High risk at case L3',
#  'CASP_D00406002222666': 'High risk at case L3',
#  'CASP_D00406002222777': 'High risk at case L3',
#  'CASP_D00406002222888': 'High risk at case L3',
#  'CASP_D00406002222999': 'High risk at case L3',
#  'CASP_D00630157111111': 'High risk at case L3',
#  'CASP_D00630157222222': 'High risk at case L3',
#  'CASP_D00630169780001': 'High risk at case L3',
#  'CASP_D00630169780002': 'High risk at case L3',
#  'CASP_D00630169780003': 'High risk at case L3',
#  'CASP_D00630169780004': 'High risk at case L3',
#  'CASP_D00630169780005': 'High risk at case L3',
#  'CASP_D00630169780006': 'High risk at case L3',
#  'CASP_D00630169780007': 'High risk at case L3',
#  'CASP_D00630169780008': 'High risk at case L3',
#  'CASP_D00630169780009': 'High risk at case H3',
#  'CASP_D00630169780010': 'High risk at case L3',
#  'CASP_D00630169780011': 'High risk at case L3',
#  'CASP_D00630169780012': 'High risk at case L3',
#  'CASP_D00630169780013': 'High risk at case L3',
#  'CASP_D00630169780014': 'High risk at case L3',
#  'CASP_D00630169780015': 'High risk at case L3',
#  'CASP_D00630169780016': 'High risk at case L3',
#  'CASP_D00630169780017': 'no risk at case H3',
#  'CASP_D00630169780018': 'High risk at case M3',
#  'CASP_D00630169780019': 'High risk at case L3',
#  'CASP_D00630169780020': 'High risk at case L3',
#  'CASP_D00630169780021': 'High risk at case L3',
#  'CASP_D00630169780022': 'High risk at case L3',
#  'CASP_D00630169780023': 'High risk at case L3',
#  'CASP_D00630169780024': 'High risk at case L3',
#  'CASP_D00630169780025': 'High risk at case L3',
#  'CASP_D00630169780026': 'High risk at case L3',
#  'CASP_D00630169780027': 'High risk at case L3',
#  'CASP_D00630169780028': 'High risk at case L3',
#  'CASP_D00630169780029': 'High risk at case L3',
#  'CASP_D00630169780030': 'High risk at case L3',
#  'CASP_D00630169780031': 'High risk at case L3',
#  'CASP_D00630169780032': 'High risk at case L3',
#  'CASP_D00630169780033': 'High risk at case L3',
#  'CASP_D00630169780034': 'High risk at case L3',
#  'CASP_D00630169780035': 'High risk at case L3',
#  'CASP_D00630169780036': 'High risk at case L3',
#  'CASP_D00630169780037': 'High risk at case L3',
#  'CASP_D00630169780038': 'High risk at case L3',
#  'CASP_D00630169780039': 'High risk at case L3',
#  'CASP_D00630169780040': 'High risk at case L3',
#  'CASP_D00630169780041': 'High risk at case L3',
#  'CASP_D00630169780042': 'High risk at case L3',
#  'CASP_D00630169780043': 'High risk at case L3',
#  'CASP_D00630169780044': 'High risk at case L3',
#  'CASP_D00630169780045': 'High risk at case L3',
#  'CASP_D00630169780046': 'High risk at case L3',
#  'CASP_D00630169780047': 'High risk at case L3',
#  'CASP_D00630169780048': 'High risk at case L3',
#  'CASP_D00630169780049': 'High risk at case L3',
#  'CASP_D00630169780050': 'High risk at case L3',
#  'CASP_D00630169780051': 'High risk at case L3',
#  'CASP_D00630169780052': 'High risk at case L3',
#  'CASP_D00630169780053': 'High risk at case L3',
#  'CASP_D00630169780054': 'High risk at case L3',
#  'CASP_D00630169780055': 'High risk at case L3',
#  'CASP_D00630169780056': 'High risk at case L3',
#  'CASP_D00630169780057': 'High risk at case L3',
#  'CASP_D00630169780058': 'High risk at case L3',
#  'CASP_D00630169780059': 'High risk at case L3',
#  'CASP_D00630169780060': 'High risk at case L3',
#  'CASP_D00630169780061': 'High risk at case L3',
#  'CASP_D00630169780062': 'High risk at case L3',
#  'CASP_D00630169780063': 'High risk at case L3',
#  'CASP_D00630169780064': 'High risk at case L3',
#  'CASP_D00630169780065': 'High risk at case L3',
#  'CASP_D00630169780066': 'High risk at case L3',
#  'CASP_D00630169780067': 'High risk at case L3',
#  'CASP_D00630169780068': 'High risk at case L3',
#  'CASP_D00630169780069': 'High risk at case L3',
#  'CASP_D00630169780070': 'High risk at case L3',
#  'CASP_D00630169780071': 'High risk at case L3',
#  'CASP_D00630169780072': 'High risk at case L3',
#  'CASP_D00630169780073': 'High risk at case L3',
#  'CASP_D00630169780074': 'High risk at case L3',
#  'CASP_D00630169780075': 'High risk at case L3',
#  'CASP_D00630169780076': 'High risk at case L3',
#  'CASP_D00630169780077': 'High risk at case L3',
#  'CASP_D00630169780078': 'High risk at case L3',
#  'CASP_D00630169780079': 'High risk at case L3',
#  'CASP_D00630169780080': 'High risk at case L3',
#  'CASP_D00630169780081': 'High risk at case L3',
#  'CASP_D00630169780082': 'High risk at case L3',
#  'CASP_D00630169780083': 'High risk at case L3',
#  'CASP_D00630169780084': 'High risk at case L3',
#  'CASP_D00630169780085': 'High risk at case L3',
#  'CASP_D00630169780086': 'High risk at case L3',
#  'CASP_D00630169780087': 'High risk at case L3',
#  'CASP_D00630169780088': 'High risk at case L3',
#  'CASP_D00630169780089': 'High risk at case L3',
#  'CASP_D00630169780090': 'High risk at case L3',
#  'CASP_D00630169780091': 'High risk at case L3',
#  'CASP_D00630169780092': 'High risk at case L3',
#  'CASP_D00630169780093': 'High risk at case L3',
#  'CASP_D00630169780094': 'High risk at case L3',
#  'CASP_D00630169780095': 'High risk at case L3',
#  'CASP_D00630169780096': 'High risk at case L3',
#  'CASP_D00630169780097': 'High risk at case L3',
#  'CASP_D00630169780098': 'High risk at case L3',
#  'CASP_D00630169780099': 'High risk at case L3',
#  'CASP_D00630169780100': 'High risk at case L3',
#  'CASP_D00630169780101': 'High risk at case L3',
#  'CASP_D00630169780102': 'High risk at case L3',
#  'CASP_D00630169780103': 'High risk at case L3',
#  'CASP_D00630169780104': 'High risk at case L3',
#  'CASP_D00630169780105': 'High risk at case L3',
#  'CASP_D00630169780106': 'High risk at case L3',
#  'CASP_D00630169780107': 'High risk at case L3',
#  'CASP_D00630169780108': 'High risk at case L3',
#  'CASP_D00630169780109': 'High risk at case L3',
#  'CASP_D00630169780110': 'High risk at case L3',
#  'CASP_D00630169780111': 'High risk at case L3',
#  'CASP_D00630169780112': 'High risk at case L3',
#  'CASP_D00630169780113': 'High risk at case L3',
#  'CASP_D00630169780114': 'High risk at case L3',
#  'CASP_D00630169780115': 'High risk at case L3',
#  'CASP_D00630169780116': 'High risk at case L3',
#  'CASP_D00630169780117': 'High risk at case L3',
#  'CASP_D00630169780118': 'High risk at case L3',
#  'CASP_D00630169780119': 'High risk at case L3',
#  'CASP_D00630169780120': 'High risk at case L3',
#  'CASP_D00630169780121': 'High risk at case L3',
#  'CASP_D00630169780122': 'High risk at case L3',
#  'CASP_D00630169780123': 'High risk at case L3',
#  'CASP_D00630169780124': 'High risk at case L3',
#  'CASP_D00630169780125': 'High risk at case L3',
#  'CASP_D00630169780126': 'High risk at case L3',
#  'CASP_D00630169780127': 'High risk at case L3',
#  'CASP_D00630169780128': 'High risk at case L3',
#  'CASP_D00630169780129': 'High risk at case L3',
#  'CASP_D00630169780130': 'High risk at case L3',
#  'CASP_D00630169780131': 'High risk at case L3',
#  'CASP_D00630169780132': 'High risk at case L3',
#  'CASP_D00630169780133': 'High risk at case L3',
#  'CASP_D00630169780134': 'High risk at case L3',
#  'CASP_D00630169780135': 'High risk at case L3',
#  'CASP_D00630169780136': 'High risk at case L3',
#  'CASP_D00630169780137': 'High risk at case L3',
#  'CASP_D00630169780138': 'High risk at case L3',
#  'CASP_D00630169780139': 'High risk at case L3',
#  'CASP_D00630169780140': 'High risk at case L3',
#  'CASP_D00630169780141': 'High risk at case L3',
#  'CASP_D00630169780142': 'High risk at case L3',
#  'CASP_D00630169780143': 'High risk at case L3',
#  'CASP_D00630169780144': 'High risk at case L3',
#  'CASP_D00630169780145': 'High risk at case L3',
#  'CASP_D00630169780146': 'High risk at case L3',
#  'CASP_D00630169780147': 'High risk at case L3',
#  'CASP_D00630169780148': 'High risk at case L3',
#  'CASP_D00630169780149': 'High risk at case L3',
#  'CASP_D00630169780150': 'High risk at case L3',
#  'CASP_D00630169780151': 'High risk at case L3',
#  'CASP_D00630169780152': 'High risk at case L3',
#  'CASP_D00630169780153': 'High risk at case L3',
#  'CASP_D00630169780154': 'High risk at case L3',
#  'CASP_D00630169780155': 'High risk at case L3',
#  'CASP_D00630169780156': 'High risk at case L3',
#  'CASP_D00630169780157': 'High risk at case L3',
#  'CASP_D00630169780158': 'High risk at case L3',
#  'CASP_D00630169780159': 'High risk at case L3',
#  'CASP_D00630169780160': 'High risk at case L3',
#  'CASP_D00630169780161': 'High risk at case L3',
#  'CASP_D00630169780162': 'High risk at case L3',
#  'CASP_D00630169780163': 'High risk at case L3',
#  'CASP_D00630169780164': 'High risk at case L3',
#  'CASP_D00630169780165': 'High risk at case L3',
#  'CASP_D00630169780166': 'High risk at case L3',
#  'CASP_D00630169780167': 'High risk at case L3',
#  'CASP_D00630169780168': 'High risk at case L3',
#  'CASP_D00630169780169': 'High risk at case L3',
#  'CASP_D00630169780170': 'High risk at case L3',
#  'CASP_D00630169780171': 'High risk at case L3',
#  'CASP_D00630169780172': 'High risk at case L3',
#  'CASP_D00630169780173': 'High risk at case L3',
#  'CASP_D00630169780174': 'High risk at case L3',
#  'CASP_D00630169780175': 'High risk at case L3',
#  'CASP_D00630169780176': 'High risk at case L3',
#  'CASP_D00630169780177': 'High risk at case L3',
#  'CASP_D00630169780178': 'High risk at case L3',
#  'CASP_D00630169780179': 'High risk at case L3',
#  'CASP_D00630169780180': 'High risk at case L3',
#  'CASP_D00630169780181': 'High risk at case L3',
#  'CASP_D00630169780182': 'High risk at case L3',
#  'CASP_D00630169780183': 'High risk at case L3',
#  'CASP_D00630169780184': 'High risk at case L3',
#  'CASP_D00630169780185': 'High risk at case L3',
#  'CASP_D00630169780186': 'High risk at case L3',
#  'CASP_D00630169780187': 'High risk at case L3',
#  'CASP_D00630169780188': 'High risk at case L3',
#  'CASP_D00630169780189': 'High risk at case L3',
#  'CASP_D00630169780190': 'High risk at case L3',
#  'CASP_D00630169780191': 'High risk at case L3',
#  'CASP_D00630169780192': 'High risk at case L3',
#  'CASP_D00630169780193': 'High risk at case L3',
#  'CASP_D00630169780194': 'High risk at case L3',
#  'CASP_D00630169780195': 'High risk at case L3',
#  'CASP_D00630169780196': 'High risk at case L3',
#  'CASP_D00630169780197': 'High risk at case L3',
#  'CASP_D00630169780198': 'High risk at case L3',
#  'CASP_D00630169780199': 'High risk at case L3',
#  'CASP_D00630169780200': 'High risk at case L3',
#  'CASP_D00630169780201': 'High risk at case L3',
#  'CASP_D00630169780202': 'High risk at case L3',
#  'CASP_D00630169780203': 'High risk at case L3',
#  'CASP_D00630169780204': 'High risk at case L3',
#  'CASP_D00630169780205': 'High risk at case L3',
#  'CASP_D00630169780206': 'High risk at case L3',
#  'CASP_D00630169780207': 'High risk at case L3',
#  'CASP_D00630169780208': 'High risk at case L3',
#  'CASP_D00630169780209': 'High risk at case L3',
#  'CASP_D00630169780210': 'High risk at case L3',
#  'CASP_D00630169780211': 'High risk at case L3',
#  'CASP_D00630169780212': 'High risk at case L3',
#  'CASP_D00630169780213': 'High risk at case L3',
#  'CASP_D00630169780214': 'High risk at case L3',
#  'CASP_D00630169780215': 'High risk at case L3',
#  'CASP_D00630169780216': 'High risk at case L3',
#  'CASP_D00630169780217': 'High risk at case L3',
#  'CASP_D00630169780218': 'High risk at case L3',
#  'CASP_D00630169780219': 'High risk at case L3',
#  'CASP_D00630169780220': 'High risk at case L3',
#  'CASP_D00630169780221': 'High risk at case L3',
#  'CASP_D00630169780222': 'High risk at case L3',
#  'CASP_D00630169780223': 'High risk at case L3',
#  'CASP_D00630169780224': 'High risk at case L3',
#  'CASP_D00630169780225': 'High risk at case L3',
#  'CASP_D00630169780226': 'High risk at case L3',
#  'CASP_D00630169780227': 'High risk at case L3',
#  'CASP_D00630169780228': 'High risk at case L3',
#  'CASP_D00630169780229': 'High risk at case L3',
#  'CASP_D00630169780230': 'High risk at case L3',
#  'CASP_D00630169780231': 'High risk at case L3',
#  'CASP_D00630169780232': 'High risk at case L3',
#  'CASP_D00630169780233': 'High risk at case L3',
#  'CASP_D00630169780234': 'High risk at case L3',
#  'CASP_D00630169780235': 'High risk at case L3',
#  'CASP_D00630169780236': 'High risk at case L3',
#  'CASP_D00630169780237': 'High risk at case L3',
#  'CASP_D00630169780238': 'High risk at case L3',
#  'CASP_D00630169780239': 'High risk at case L3',
#  'CASP_D00630169780240': 'High risk at case L3',
#  'CASP_D00630169780241': 'High risk at case L3',
#  'CASP_D00630169780242': 'High risk at case L3',
#  'CASP_D00630169780243': 'High risk at case L3',
#  'CASP_D00630169780244': 'High risk at case L3',
#  'CASP_D00630169780245': 'High risk at case L3',
#  'CASP_D00630169780246': 'High risk at case L3',
#  'CASP_D00630169780247': 'High risk at case L3',
#  'CASP_D00630169780248': 'High risk at case L3',
#  'CASP_D00630169780249': 'High risk at case L3',
#  'CASP_D00630169780250': 'High risk at case L3',
#  'CASP_D00630169780251': 'High risk at case L3',
#  'CASP_D00630169780252': 'High risk at case L3',
#  'CASP_D00630169780253': 'High risk at case L3',
#  'CASP_D00630169780254': 'High risk at case L3',
#  'CASP_D00630412222000': 'High risk at case L3',
#  'CASP_D00630412222111': 'High risk at case L3',
#  'CASP_D00630412222222': 'High risk at case L3',
#  'CASP_D00630412222333': 'High risk at case L3',
#  'CASP_D00630412222444': 'High risk at case L3',
#  'CASP_D00630412222555': 'High risk at case L3',
#  'CASP_D00630412222666': 'High risk at case L3',
#  'CASP_D00630412222777': 'High risk at case L3',
#  'CASP_D04050165300009': 'High risk at case L3',
#  'CASP_D19900122220211': 'High risk at case L3',
#  'CASP_D19900122220212': 'High risk at case L3',
#  'CASP_D20100169780240': 'High risk at case L3',
#  'CASP_D20100169780241': 'High risk at case L3',
#  'CASP_D20100169780242': 'High risk at case L3',
#  'CASP_D20100169780243': 'High risk at case L3',
#  'CASP_D20100169780244': 'High risk at case L3',
#  'CASP_D20100169780245': 'High risk at case L3',
#  'CASP_D20100169780246': 'High risk at case L3',
#  'CASP_D20100169780247': 'High risk at case L3',
#  'CASP_D20100169780248': 'High risk at case L3',
#  'CASP_D20100169780249': 'High risk at case L3',
#  'CASP_D20100169780250': 'High risk at case L3',
#  'CASP_D20100169780251': 'High risk at case L3',
#  'CASP_D20100169780252': 'High risk at case L3',
#  'CASP_D20100169780253': 'High risk at case L3',
#  'CASP_D20100169780254': 'High risk at case L3',
#  'CASP_D20100169780255': 'High risk at case L3',
#  'CASP_D20100169780256': 'High risk at case L3',
#  'CASP_D20100169780257': 'High risk at case L3',
#  'CASP_D20100169780258': 'High risk at case L3',
#  'CASP_D20100169780259': 'High risk at case L3',
#  'CASP_D20100169780260': 'High risk at case L3',
#  'CASP_D20100169780261': 'High risk at case L3',
#  'CASP_D20100169780262': 'High risk at case L3',
#  'CASP_D20100169780263': 'High risk at case L3',
#  'CASP_D20100169780264': 'High risk at case L3',
#  'CASP_D20100169780265': 'High risk at case L3',
#  'CASP_D20100169780266': 'High risk at case L3',
#  'CASP_D20100169780267': 'High risk at case L3',
#  'CASP_D20100169780268': 'High risk at case L3',
#  'CASP_D20100169780269': 'High risk at case L3',
#  'CASP_D20100169780270': 'High risk at case L3',
#  'CASP_D20100169780271': 'High risk at case L3',
#  'CASP_D20100169780272': 'High risk at case L3',
#  'CASP_D20100169780273': 'High risk at case L3',
#  'CASP_D20100169780274': 'High risk at case L3',
#  'CASP_D20100169780275': 'High risk at case L3',
#  'CASP_D20100169780276': 'High risk at case L3',
#  'CASP_D28700122220000': 'High risk at case L3',
#  'CASP_D33590169780249': 'High risk at case L3',
#  'CASP_D33590169780250': 'High risk at case L3',
#  'CASP_D34300122220211': 'High risk at case L3',
#  'CASP_D34300169780211': 'High risk at case L3',
#  'CASP_D34300169780212': 'High risk at case L3',
#  'CASP_D34300169780213': 'High risk at case L3',
#  'CASP_D34300169780214': 'High risk at case L3',
#  'CASP_D34300169780215': 'High risk at case L3',
#  'CASP_D34300169780216': 'High risk at case L3',
#  'CASP_D34300169780217': 'High risk at case L3',
#  'CASP_D34300169780218': 'High risk at case L3',
#  'CASP_D34300169780219': 'High risk at case L3',
#  'CASP_D34300169780220': 'High risk at case L3',
#  'CASP_D34300169780221': 'High risk at case L3',
#  'CASP_D34300169780222': 'High risk at case L3',
#  'CASP_D34300169780223': 'High risk at case L3',
#  'CASP_D34300169780224': 'High risk at case L3',
#  'CASP_D34300169780225': 'High risk at case L3',
#  'CASP_D34300169780226': 'High risk at case L3',
#  'CASP_D34300169780227': 'High risk at case L3',
#  'CASP_D34300169780228': 'High risk at case L3',
#  'CASP_D34300169780229': 'High risk at case L3',
#  'CASP_D34300169780230': 'High risk at case L3',
#  'CASP_D34300169780231': 'High risk at case L3',
#  'CASP_D34300169780232': 'High risk at case L3',
#  'CASP_D34300169780233': 'High risk at case L3',
#  'CASP_D34300169780234': 'High risk at case L3',
#  'CASP_D34300169780235': 'High risk at case L3',
#  'CASP_D34300169780236': 'High risk at case L3',
#  'CASP_D34300169780237': 'High risk at case L3',
#  'CASP_D34300169780238': 'High risk at case L3',
#  'CASP_D34300169780239': 'High risk at case L3',
#  'CASP_D34300169780240': 'High risk at case L3',
#  'CASP_D34300169780241': 'High risk at case L3',
#  'CASP_D34300169780242': 'High risk at case L3',
#  'CASP_D34300169780243': 'High risk at case L3',
#  'CASP_D34300169780244': 'High risk at case L3',
#  'CASP_D34300169780245': 'High risk at case L3',
#  'CASP_D34300169780246': 'High risk at case L3',
#  'CASP_D34300169780247': 'High risk at case L3',
#  'CASP_D34300169780248': 'High risk at case L3',
#  'CASP_D34300169780249': 'High risk at case L3',
#  'CASP_D34300169780250': 'High risk at case L3',
#  'CASP_D34300169780251': 'High risk at case L3',
#  'CASP_D34300169780252': 'High risk at case L3',
#  'CASP_D34300169780253': 'High risk at case L3',
#  'CASP_D34300169780254': 'High risk at case L3',
#  'CASP_D34300169780255': 'High risk at case L3',
#  'CASP_D34300169780256': 'High risk at case L3',
#  'CASP_D34300169780257': 'High risk at case L3',
#  'CASP_D34300169780258': 'High risk at case L3',
#  'CASP_D34300169780259': 'High risk at case L3',
#  'CASP_D34300169780260': 'High risk at case L3',
#  'CASP_D34300169780261': 'High risk at case L3',
#  'CASP_D34300169780262': 'High risk at case L3',
#  'CASP_D34300169780263': 'High risk at case L3',
#  'CASP_D34300169780264': 'High risk at case L3',
#  'CASP_D34300169780265': 'High risk at case L3',
#  'CASP_D34300169780266': 'High risk at case L3',
#  'CASP_D34300169780267': 'High risk at case L3',
#  'CASP_D34300169780268': 'High risk at case L3',
#  'CASP_D34300169780280': 'High risk at case L3',
#  'CASP_D34300169780291': 'High risk at case L3',
#  'CASP_D35230169780240': 'High risk at case L3',
#  'CASP_D35230169780241': 'High risk at case L3',
#  'CASP_D35230169780242': 'High risk at case L3',
#  'CASP_D35230169780243': 'High risk at case L3',
#  'CASP_D35230169780244': 'High risk at case L3',
#  'CASP_D35230169780245': 'High risk at case L3',
#  'CASP_D35230169780246': 'High risk at case L3',
#  'CASP_D35230169780247': 'High risk at case L3',
#  'CASP_D35230169780248': 'High risk at case L3',
#  'CASP_D35230169780249': 'High risk at case L3',
#  'CASP_D35630169780241': 'High risk at case L3',
#  'CASP_D35630169780242': 'High risk at case L3',
#  'CASP_D35630169780243': 'High risk at case L3',
#  'CASP_D35630169780244': 'High risk at case L3',
#  'CASP_D35630169780245': 'High risk at case L3',
#  'CASP_D35630169780246': 'High risk at case L3',
#  'CASP_D35630169780247': 'High risk at case L3',
#  'CASP_D35630169780248': 'High risk at case L3',
#  'CASP_D35630169780249': 'High risk at case L3',
#  'CASP_D35630169780250': 'High risk at case L3',
#  'CASP_D35630169780251': 'High risk at case L3',
#  'CASP_D35630169780252': 'High risk at case L3',
#  'CASP_D35630169780253': 'High risk at case L3',
#  'CASP_D35630169780254': 'High risk at case L3',
#  'CASP_D35630169780255': 'High risk at case L3',
#  'CASP_D35630169780256': 'High risk at case L3',
#  'CASP_D35630169780257': 'High risk at case L3',
#  'CASP_D35630169780258': 'High risk at case L3',
#  'CASP_D35630169780259': 'High risk at case L3',
#  'CASP_D35630169780260': 'High risk at case L3',
#  'CASP_D35630169780261': 'High risk at case L3',
#  'CASP_D35630169780262': 'High risk at case L3',
#  'CASP_D35630169780263': 'High risk at case L3',
#  'CASP_D35630169780264': 'High risk at case L3',
#  'CASP_D35630169780265': 'High risk at case L3',
#  'CASP_D35630169780266': 'High risk at case L3',
#  'CASP_D36030169780241': 'High risk at case L3',
#  'CASP_D36030169780242': 'High risk at case L3',
#  'CASP_D36030169780243': 'High risk at case L3',
#  'CASP_D37130169780241': 'High risk at case L3',
#  'CASP_D37230169780241': 'High risk at case L3',
#  'CASP_D37230169780242': 'High risk at case L3',
#  'CASP_D37230169780243': 'High risk at case L3',
#  'CASP_D37230169780244': 'High risk at case L3',
#  'CASP_D37230169780245': 'High risk at case L3',
#  'CASP_D37230169780246': 'High risk at case L3',
#  'CASP_D37230169780247': 'High risk at case L3',
#  'CASP_D37230169780248': 'High risk at case L3',
#  'CASP_D37230169780249': 'High risk at case L3',
#  'CASP_D37700169780111': 'High risk at case L3',
#  'CASP_D37700169780222': 'High risk at case L3',
#  'CASP_D40000000001111': 'High risk at case L3',
#  'CASP_D40000000002222': 'High risk at case L3',
#  'CASP_D40300122220000': 'High risk at case L3',
#  'CASP_D40500169711110': 'High risk at case L3',
#  'CASP_D40500169711111': 'High risk at case L3',
#  'CASP_D40500169733330': 'High risk at case L3',
#  'CASP_D40500169733331': 'High risk at case L3',
#  'CASP_D40500169744440': 'High risk at case L3',
#  'CASP_D40500169755550': 'High risk at case L3',
#  'CASP_D40500169755551': 'High risk at case L3',
#  'CASP_D40500169766661': 'High risk at case L3',
#  'CASP_D40500169777770': 'High risk at case L3',
#  'CASP_D40500169777771': 'High risk at case L3',
#  'CASP_D40500169780222': 'High risk at case L3',
#  'CASP_D40500169799999': 'High risk at case L3',
#  'CASP_D40500169888888': 'High risk at case L3',
#  'CASP_D41300000001111': 'High risk at case L3',
#  'CASP_D41300000001123': 'High risk at case L3',
#  'CASP_D41300000002222': 'High risk at case L3',
#  'CASP_D41300000002456': 'High risk at case L3',
#  'CASP_D41300000003333': 'High risk at case L3',
#  'CASP_D41300000003789': 'High risk at case L3',
#  'CASP_D41300000004444': 'High risk at case L3',
#  'CASP_D41300000005555': 'High risk at case L3',
#  'CASP_D41300000006666': 'High risk at case L3',
#  'CASP_D41300000007777': 'High risk at case L3',
#  'CASP_D41300000008888': 'High risk at case L3',
#  'CASP_D41300000009999': 'High risk at case L3',
#  'CASP_D43700000001111': 'High risk at case L3',
#  'CASP_D43700000002222': 'High risk at case L3',
#  'CASP_D43700000003333': 'High risk at case L3',
#  'CASP_P34300169780269': 'High risk at case L3',
#  'DQSP_D34300169780271': 'High risk at case L3',
#  'DQSP_P34300169780272': 'High risk at case L3',
#  nan: 'High risk at case L3'}

# %%
df2=df1.loc[df[' Transaction Type']=="INN"]
if sum(df2[" Transaction_Amount(in $)"])>1000:
    print("High risk at case H2")
elif sum(df2[" Transaction_Amount(in $)"])<1000 and sum(df2[" Transaction_Amount(in $)"])>600:
  print("low risk at case M2")
elif sum(df2[" Transaction_Amount(in $)"])<600:
  print("low risk at case L2")
else:
    print("no risk at case H2")
# Out:
# High risk at case H2

# %%
df2=df1.loc[df[' Transaction Type']=="OUT"]
if sum(df2[" Transaction_Amount(in $)"])>800:
    print("High risk at case H3")
elif sum(df2[" Transaction_Amount(in $)"])<800 and sum(df2[" Transaction_Amount(in $)"])>500:
  print("High risk at case M3")
elif sum(df2[" Transaction_Amount(in $)"])<500:
  print("High risk at case L3")
else:
    print("no risk at case H3")
# Out:
# High risk at case L3
